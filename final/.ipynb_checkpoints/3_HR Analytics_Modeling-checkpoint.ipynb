# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10740483535840392211
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 5736300544
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3140827092688378393
# physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:2b:00.0, compute capability: 8.6"
# ]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, log_loss, confusion_matrix, roc_curve, roc_auc_score
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from imblearn.over_sampling import SMOTE
import warnings, graphviz, optuna, pydot
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.utils import to_categorical
warnings.filterwarnings('ignore')
sns.set(style='white')
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 13
plt.rcParams['axes.labelweight'] = 'bold'
np.random.seed(0)
tf.random.set_seed(0)

# %%
trn = pd.read_csv('aug_train.csv')
tst = pd.read_csv('aug_test.csv')
tst_answer = np.load('jobchange_test_target_values.npy')
tst['target'] = tst_answer
trn.drop('enrollee_id', axis=1, inplace=True)
tst.drop('enrollee_id', axis=1, inplace=True)
trn['city'] = trn['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))
tst['city'] = tst['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))

# 모든 Null 값을 Missing으로 변경합니다.
for col in tst.columns:
    trn[col].fillna('Missing', inplace=True)
    tst[col].fillna('Missing', inplace=True)
    
# Missing 값의 갯수 Feature 생성
trn['num_missing'] = (trn=='Missing').sum(axis=1)
tst['num_missing'] = (tst=='Missing').sum(axis=1)
    
print(f"train data size: {trn.shape}, test data size: {tst.shape}")
trn.head(2)
# Out:
# train data size: (19158, 14), test data size: (2129, 14)
#        city  city_development_index gender      relevent_experience  \
# 0  city_103                   0.920   Male  Has relevent experience
# 1  city_040                   0.776   Male   No relevent experience
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
#
#   company_size company_type last_new_job  training_hours  target  num_missing
# 0      Missing      Missing            1              36     1.0            2
# 1        50-99      Pvt Ltd           >4              47     0.0            0

# %%
trn_info = pd.concat(
    [
        trn.dtypes,        
        trn.isnull().sum(),
        trn.isnull().sum() / trn.shape[0],
        trn.nunique(),
        tst.nunique()
    ], axis=1
)
trn_info.columns=['data_types', 'Num_of_Null', 'Null_ratio', 'Num_of_unique_values(train)', 'Num_of_unique_values(test)']
trn_info.iloc[:-1, :].style.background_gradient()
# Null값이 상당히 많습니다.
# Out:
# <style type="text/css">
# #T_c252e_row0_col1, #T_c252e_row0_col2, #T_c252e_row1_col1, #T_c252e_row1_col2, #T_c252e_row2_col1, #T_c252e_row2_col2, #T_c252e_row3_col1, #T_c252e_row3_col2, #T_c252e_row3_col3, #T_c252e_row3_col4, #T_c252e_row4_col1, #T_c252e_row4_col2, #T_c252e_row5_col1, #T_c252e_row5_col2, #T_c252e_row6_col1, #T_c252e_row6_col2, #T_c252e_row7_col1, #T_c252e_row7_col2, #T_c252e_row8_col1, #T_c252e_row8_col2, #T_c252e_row9_col1, #T_c252e_row9_col2, #T_c252e_row10_col1, #T_c252e_row10_col2, #T_c252e_row11_col1, #T_c252e_row11_col2, #T_c252e_row12_col1, #T_c252e_row12_col2, #T_c252e_row12_col3, #T_c252e_row12_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c252e_row0_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_c252e_row0_col4 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_c252e_row1_col3 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_c252e_row1_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_c252e_row2_col3, #T_c252e_row2_col4, #T_c252e_row4_col3, #T_c252e_row4_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c252e_row5_col3, #T_c252e_row5_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c252e_row6_col3, #T_c252e_row6_col4, #T_c252e_row9_col3, #T_c252e_row9_col4, #T_c252e_row10_col3, #T_c252e_row10_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c252e_row7_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c252e_row7_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_c252e_row8_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_c252e_row8_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c252e_row11_col3, #T_c252e_row11_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c252e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >data_types</th>
#       <th class="col_heading level0 col1" >Num_of_Null</th>
#       <th class="col_heading level0 col2" >Null_ratio</th>
#       <th class="col_heading level0 col3" >Num_of_unique_values(train)</th>
#       <th class="col_heading level0 col4" >Num_of_unique_values(test)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c252e_level0_row0" class="row_heading level0 row0" >city</th>
#       <td id="T_c252e_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_c252e_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c252e_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_c252e_row0_col3" class="data row0 col3" >123</td>
#       <td id="T_c252e_row0_col4" class="data row0 col4" >108</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row1" class="row_heading level0 row1" >city_development_index</th>
#       <td id="T_c252e_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_c252e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_c252e_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c252e_row1_col3" class="data row1 col3" >93</td>
#       <td id="T_c252e_row1_col4" class="data row1 col4" >81</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row2" class="row_heading level0 row2" >gender</th>
#       <td id="T_c252e_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_c252e_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_c252e_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_c252e_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_c252e_row2_col4" class="data row2 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row3" class="row_heading level0 row3" >relevent_experience</th>
#       <td id="T_c252e_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_c252e_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_c252e_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_c252e_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_c252e_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row4" class="row_heading level0 row4" >enrolled_university</th>
#       <td id="T_c252e_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_c252e_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c252e_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_c252e_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_c252e_row4_col4" class="data row4 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row5" class="row_heading level0 row5" >education_level</th>
#       <td id="T_c252e_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_c252e_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_c252e_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_c252e_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_c252e_row5_col4" class="data row5 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row6" class="row_heading level0 row6" >major_discipline</th>
#       <td id="T_c252e_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_c252e_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_c252e_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_c252e_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_c252e_row6_col4" class="data row6 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row7" class="row_heading level0 row7" >experience</th>
#       <td id="T_c252e_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_c252e_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_c252e_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_c252e_row7_col3" class="data row7 col3" >23</td>
#       <td id="T_c252e_row7_col4" class="data row7 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row8" class="row_heading level0 row8" >company_size</th>
#       <td id="T_c252e_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_c252e_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_c252e_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_c252e_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_c252e_row8_col4" class="data row8 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row9" class="row_heading level0 row9" >company_type</th>
#       <td id="T_c252e_row9_col0" class="data row9 col0" >object</td>
#       <td id="T_c252e_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_c252e_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_c252e_row9_col3" class="data row9 col3" >7</td>
#       <td id="T_c252e_row9_col4" class="data row9 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row10" class="row_heading level0 row10" >last_new_job</th>
#       <td id="T_c252e_row10_col0" class="data row10 col0" >object</td>
#       <td id="T_c252e_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_c252e_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_c252e_row10_col3" class="data row10 col3" >7</td>
#       <td id="T_c252e_row10_col4" class="data row10 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row11" class="row_heading level0 row11" >training_hours</th>
#       <td id="T_c252e_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_c252e_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_c252e_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_c252e_row11_col3" class="data row11 col3" >241</td>
#       <td id="T_c252e_row11_col4" class="data row11 col4" >223</td>
#     </tr>
#     <tr>
#       <th id="T_c252e_level0_row12" class="row_heading level0 row12" >target</th>
#       <td id="T_c252e_row12_col0" class="data row12 col0" >float64</td>
#       <td id="T_c252e_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_c252e_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_c252e_row12_col3" class="data row12 col3" >2</td>
#       <td id="T_c252e_row12_col4" class="data row12 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
for col in trn.select_dtypes(include='object').columns:
    print(f"{col} feature의 unique value train/test 동일 여부: {sorted(trn[col].unique()) == sorted(tst[col].unique())}")
print("="*100)
# city를 빼고는 train과 test 셋의 unique values가 동일합니다.
# 문제는 test에는 있는 city가 train에 있을 경우 입니다. 혹시 모르니 확인해봅니다.
for city in tst['city'].unique():
    if city not in trn['city'].unique():
        print('warnings!') 
# 다행히 warnings가 출력되지 않았습니다. 그럼 train 데이터를 기준으로 모두 labelencoding 하겠습니다.
# Out:
# city feature의 unique value train/test 동일 여부: False
# gender feature의 unique value train/test 동일 여부: True
# relevent_experience feature의 unique value train/test 동일 여부: True
# enrolled_university feature의 unique value train/test 동일 여부: True
# education_level feature의 unique value train/test 동일 여부: True
# major_discipline feature의 unique value train/test 동일 여부: True
# experience feature의 unique value train/test 동일 여부: True
# company_size feature의 unique value train/test 동일 여부: True
# company_type feature의 unique value train/test 동일 여부: True
# last_new_job feature의 unique value train/test 동일 여부: True
# ====================================================================================================

# %%
# 데이터 불러오기  /  labelencoding 함수 정의
def load_data():
    trn = pd.read_csv('aug_train.csv')
    tst = pd.read_csv('aug_test.csv')
    tst_answer = np.load('jobchange_test_target_values.npy')
    tst['target'] = tst_answer
    trn.drop('enrollee_id', axis=1, inplace=True)
    tst.drop('enrollee_id', axis=1, inplace=True)
    trn['city'] = trn['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))
    tst['city'] = tst['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))

    # 모든 Null 값을 Missing으로 변경합니다.
    for col in tst.columns:
        trn[col].fillna('Missing', inplace=True)
        tst[col].fillna('Missing', inplace=True)

    # Missing 값의 갯수 Feature 생성
    trn['num_missing'] = (trn=='Missing').sum(axis=1)
    tst['num_missing'] = (tst=='Missing').sum(axis=1)
    return trn, tst

def labelencoder(train, test):
    # normianl feature는 labelencoder로 처리
    norminal = ['city', 'gender', 'relevent_experience', 'major_discipline', 'company_type']
    for col in norminal:
        le = LabelEncoder()
        train[col] = le.fit_transform(train[col])
        test[col] = le.transform(test[col])

    # ordinal feature는 자체적으로 생성한 dictionary로 처리합니다
    ordinal = {
        'enrolled_university':{'Full time course':3, 'Part time course':2, 'no_enrollment':1, 'Missing':0},
        'education_level':{'Phd':5, 'Masters':4, 'Graduate':3, 'High School':2, 'Primary School':1, 'Missing':0},
        'experience':{
            '>20':22, '20':21, '19':20, '18':19, '17':18, '16':17, '15':16, '14':15, '13':14, '12':13, '11':12, '10':11,
            '9':10, '8':9, '7':8, '6':7, '5':6, '4':5, '3':4, '2':3, '1':2 , '<1':1, 'Missing':0
        },
        'company_size':{'10000+':8, '5000-9999':7, '1000-4999':6, '500-999':5, '100-500':4, '50-99':3, '10/49':2, '<10':1, 'Missing':0},
        'last_new_job':{'>4':6, '4':5, '3':4, '2':3, '1':2, 'never':1, 'Missing':0}
    }
    for col in ordinal:
        train[col] = train[col].map(ordinal[col])
        test[col] = test[col].map(ordinal[col])
    return train, test

# %%
trn, tst = load_data()
trn, tst = labelencoder(trn, tst)
features = trn.drop('target', axis=1).columns
print(trn.shape, tst.shape)
trn.head(2)
# Out:
# (19158, 14) (2129, 14)
#    city  city_development_index  gender  relevent_experience  \
# 0    73                   0.920       1                    0
# 1    27                   0.776       1                    1
#
#    enrolled_university  education_level  major_discipline  experience  \
# 0                    1                3                 6          22
# 1                    1                3                 6          16
#
#    company_size  company_type  last_new_job  training_hours  target  \
# 0             0             2             2              36     1.0
# 1             3             6             6              47     0.0
#
#    num_missing
# 0            2
# 1            0

# %%
dataset_info = pd.concat(
    [
        trn.dtypes, trn.isnull().sum(), tst.dtypes, tst.isnull().sum()
    ], axis=1
)
dataset_info.columns = ['train_dtypes', 'train_Num_of_Nulls', 'test_dtypes', 'test_Num_of_Nulls']
dataset_info # 모든 feature가 numeric으로 변경되었고 Null도 없습니다. 이제 baseline model을 생성하겠습니다.
# Out:
#                        train_dtypes  train_Num_of_Nulls test_dtypes  \
# city                          int32                   0       int32
# city_development_index      float64                   0     float64
# gender                        int32                   0       int32
# relevent_experience           int32                   0       int32
# enrolled_university           int64                   0       int64
# education_level               int64                   0       int64
# major_discipline              int32                   0       int32
# experience                    int64                   0       int64
# company_size                  int64                   0       int64
# company_type                  int32                   0       int32
# last_new_job                  int64                   0       int64
# training_hours                int64                   0       int64
# target                      float64                   0     float64
# num_missing                   int64                   0       int64
#
#                         test_Num_of_Nulls
# city                                    0
# city_development_index                  0
# gender                                  0
# relevent_experience                     0
# enrolled_university                     0
# education_level                         0
# major_discipline                        0
# experience                              0
# company_size                            0
# company_type                            0
# last_new_job                            0
# training_hours                          0
# target                                  0
# num_missing                             0

# %%
# DecisionTree 시각화 부터 시작합니다.
features = trn.drop('target', axis=1).columns
# 먼저 random 모델의 성능을 확인합니다. 단순하게 모든 target을 0으로 예측하면 정확도는
print(f"모든 데이터를 0으로 예측하면 train dataset의 정확도는: {format((trn['target'].value_counts() / trn.shape[0]).values[0], '.1%')}")
print(f"모든 데이터를 0으로 예측하면 test dataset의 정확도는: {format((tst['target'].value_counts() / tst.shape[0]).values[0], '.1%')}")
# 최소한 아래 정확도는 넘겨야 합니다.
# Out:
# 모든 데이터를 0으로 예측하면 train dataset의 정확도는: 75.1%
# 모든 데이터를 0으로 예측하면 test dataset의 정확도는: 72.9%

# %%
# 먼저 트리 시각화를 위해 decisiontree 모델을 사용합니다.
model = DecisionTreeClassifier(max_depth=5)
model.fit(trn[features], trn['target'])
trn_pred = model.predict(trn[features])
tst_pred = model.predict(tst[features])
tst_pred_proba = model.predict_proba(tst[features])
print(f"accuracy_score in train dataset: {accuracy_score(trn.target, trn_pred):.1%}")
print(f"accuracy_score in test dataset: {accuracy_score(tst.target, tst_pred):.1%}")
print(f"log_loss in test dataset: {log_loss(tst.target, tst_pred_proba):.4f}")
print(f"roc_auc_score in test dataset: {roc_auc_score(tst.target, tst_pred):.4f}")
fig, axes = plt.subplots(figsize=(15, 6), ncols=2)
sns.heatmap(
    confusion_matrix(trn.target, trn_pred), ax=axes[0], annot=True, fmt=",", cbar=False, cmap='Blues',
    annot_kws={'fontweight':'bold'}
)
sns.heatmap(
    confusion_matrix(tst.target, tst_pred), ax=axes[1], annot=True, fmt=",", cbar=False, cmap='Blues',
    annot_kws={'fontweight':'bold'}
)
axes[0].set_title('Train Confusion Matrix')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')
axes[1].set_title('Test Confusion Matrix')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')
plt.show()
# 아주 약간 높습니다. 트리 시각화를 위해 최적의 max_depth를 찾아보겠습니다.
# Out:
# accuracy_score in train dataset: 79.2%
# accuracy_score in test dataset: 78.8%
# log_loss in test dataset: 0.4963
# roc_auc_score in test dataset: 0.7248

# %%
# max_depth에 따른 정확도를 시각화 합니다.
trn_acc_list, tst_acc_list = [], []
for max_depth in range(3, 20):
    model = DecisionTreeClassifier(max_depth=max_depth)
    model.fit(trn[features], trn['target'])
    trn_acc = accuracy_score(model.predict(trn[features]), trn.target)
    tst_acc = accuracy_score(model.predict(tst[features]), tst.target)    
    trn_acc_list.append(trn_acc)
    tst_acc_list.append(tst_acc)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(range(3, 20), trn_acc_list, label='train accuracy', color='grey')
ax.plot(range(3, 20), tst_acc_list, label='test accuracy', color="#d1495b")
ax.set_xlabel('Max Depth')
ax.set_ylabel('accuracy')
ax.set_yticklabels(list(format(y, ".1%") for y in ax.get_yticks()))
ax.legend(loc='upper center', ncol=2)
ax.set_title('Model Accuracy by Max Depth')
plt.show()
# max_depth 6부터 과적합입니다. 이제 max_depth 6의 트리모델을 시각화 합니다.

# %%
# DecisionTree 시각화, Max Depth는 5로 설정합니다.
model = DecisionTreeClassifier(max_depth=5)
model.fit(trn[features], trn['target'])

export_graphviz(
    model, out_file="basetree.dot", class_names='target', feature_names=features,
    filled=True, impurity=True
) #export_graphviz로 dot 파일을 생성한 후 

(graph,) = pydot.graph_from_dot_file('basetree.dot')
graph.write_png('basetree_maxdepth_5.png') #dot to png

with open("basetree.dot") as f:
    dot_graph = f.read() #위의 dot파일을 읽고
graphviz.Source(dot_graph) #graphviz.Source()로 그립니다.

# %%
def make_result_df(model_names, pred_proba_list):
    data = np.zeros((len(model_names), 3))
    for idx, pred in enumerate(pred_proba_list):
        data[idx, :] = [
            accuracy_score(tst.target, np.argmax(pred, axis=1)),
            log_loss(tst.target, pred), roc_auc_score(tst.target, np.argmax(pred, axis=1))
        ]
    data = pd.DataFrame(index=model_names, data=data, columns=['acc', 'log_loss', 'roc_score'])
    return data

# %%
# tree 시각화를 끝냈으니 이제 본격적으로 모델을 생성해보겠습니다.
# Randomforest, XGBoost, LightGBM의 모델 성능을 비교해봅니다. 
models = [
    RandomForestClassifier(n_jobs=-1, random_state=0, max_depth=5),
    XGBClassifier(n_jobs=-1, max_depth=5),
    LGBMClassifier(n_jobs=-1)
]
pred_proba_list = []
for model in models:
    result = cross_val_score(model, X=trn[features], y=trn.target, cv=5, scoring='neg_log_loss')
    model.fit(trn[features], trn.target)
    tst_preds = model.predict(tst[features])
    pred_proba_list.append(model.predict_proba(tst[features]))

model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)']
result = make_result_df(model_names, pred_proba_list)
result
# Out:
# [10:20:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:26] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                            acc  log_loss  roc_score
# RandomForest          0.782997  0.462287   0.676504
# XGBClassifier         0.774542  0.472222   0.694191
# LGBMClassifier(base)  0.783466  0.460133   0.719422

# %%
# 이번에는 LightGBM 모델을 튜닝해보겠습니다.
def lgbm_object(trial:optuna.Trial, trn):
    X_trn, X_vld, y_trn, y_vld = train_test_split(trn[features], trn.target, test_size=0.2, random_state=0)
    params = {
        # 각 항목에 대해서 자세히 설명은 구글을 참고해주시기 바랍니다. feature가 몇개 없으므로 gamma, reg_lambda와 reg_alpha는 사용하지 않겠습니다.
        'learning_rate' : trial.suggest_float('learning_rate', 0.01, 0.1),
        'min_child_weight' : trial.suggest_int('min_child_weight', 1, 7),
        'min_child_samples' : trial.suggest_int('min_child_samples', 5, 100),
        'subsample' : trial.suggest_float('subsample', 0.5, 1),                
        'colsample_bytree' : trial.suggest_float('colsample_bytree', 0.5, 1),
        'num_leaves' : trial.suggest_int('num_leaves', 2, 256),
        'max_bin' : trial.suggest_int('max_bin', 200, 500),
        'reg_alpha' : trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda' : trial.suggest_float('reg_lambda', 0, 1),  
        'n_estimators' : trial.suggest_int('n_estimators', 100, 500),
    }
    model = LGBMClassifier(**params, seed=0, n_jobs=-1)
    model.fit(X_trn, y_trn, verbose=0)
    return log_loss(y_vld, model.predict_proba(X_vld)) # 모델의 최종 결과값을 반환합니다.
# 평가지표가 log_loss이므로 direction은 minimize 입니다.
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=0))
study.optimize(lambda trial : lgbm_object(trial, trn), n_trials=1000, n_jobs=-1)
# Out:
# [I 2021-09-30 10:20:28,258] A new study created in memory with name: no-name-4b0147b1-8379-4701-88f2-bc1edde78d58
# [I 2021-09-30 10:20:30,090] Trial 23 finished with value: 0.4362609542369093 and parameters: {'learning_rate': 0.021394916739290875, 'min_child_weight': 7, 'min_child_samples': 42, 'subsample': 0.6910870744968434, 'colsample_bytree': 0.6961977087538245, 'num_leaves': 9, 'max_bin': 271, 'reg_alpha': 0.985697638504845, 'reg_lambda': 0.7863635893335451, 'n_estimators': 410}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:32,272] Trial 10 finished with value: 0.45221214745063526 and parameters: {'learning_rate': 0.08849279065684959, 'min_child_weight': 5, 'min_child_samples': 63, 'subsample': 0.8327369079685889, 'colsample_bytree': 0.5978769382242003, 'num_leaves': 78, 'max_bin': 232, 'reg_alpha': 0.5438119336581059, 'reg_lambda': 0.38187137452389375, 'n_estimators': 122}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:32,690] Trial 20 finished with value: 0.4551893689299092 and parameters: {'learning_rate': 0.09759384486415469, 'min_child_weight': 7, 'min_child_samples': 43, 'subsample': 0.5821148466622481, 'colsample_bytree': 0.5042453473025106, 'num_leaves': 48, 'max_bin': 223, 'reg_alpha': 0.1333062206752471, 'reg_lambda': 0.010850540750758308, 'n_estimators': 186}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:32,747] Trial 17 finished with value: 0.4414834282031323 and parameters: {'learning_rate': 0.012169343104217249, 'min_child_weight': 6, 'min_child_samples': 93, 'subsample': 0.723932160337329, 'colsample_bytree': 0.8621728333625507, 'num_leaves': 222, 'max_bin': 421, 'reg_alpha': 0.45142222160014656, 'reg_lambda': 0.7538672705476188, 'n_estimators': 150}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:33,244] Trial 16 finished with value: 0.4513680154545123 and parameters: {'learning_rate': 0.06764855934241341, 'min_child_weight': 4, 'min_child_samples': 46, 'subsample': 0.5442460036766146, 'colsample_bytree': 0.7906256735193918, 'num_leaves': 91, 'max_bin': 458, 'reg_alpha': 0.10344778024257462, 'reg_lambda': 0.995640079123477, 'n_estimators': 129}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:33,338] Trial 11 finished with value: 0.45634181670860613 and parameters: {'learning_rate': 0.08851842092556404, 'min_child_weight': 1, 'min_child_samples': 84, 'subsample': 0.9551319389147122, 'colsample_bytree': 0.7820772030745698, 'num_leaves': 249, 'max_bin': 256, 'reg_alpha': 0.0744315566208672, 'reg_lambda': 0.8929848825553821, 'n_estimators': 108}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:34,433] Trial 7 finished with value: 0.47026126113001887 and parameters: {'learning_rate': 0.09579979667633998, 'min_child_weight': 7, 'min_child_samples': 38, 'subsample': 0.861393486990992, 'colsample_bytree': 0.8888730438705843, 'num_leaves': 46, 'max_bin': 332, 'reg_alpha': 0.7568069726121491, 'reg_lambda': 0.4725949180465693, 'n_estimators': 299}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:34,938] Trial 2 finished with value: 0.4401729295736388 and parameters: {'learning_rate': 0.022175558304215637, 'min_child_weight': 6, 'min_child_samples': 93, 'subsample': 0.563676156678845, 'colsample_bytree': 0.8771642315430588, 'num_leaves': 187, 'max_bin': 240, 'reg_alpha': 0.22348506586627848, 'reg_lambda': 0.5349943039269394, 'n_estimators': 164}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:36,043] Trial 14 finished with value: 0.4537134148514537 and parameters: {'learning_rate': 0.040962734757402114, 'min_child_weight': 6, 'min_child_samples': 59, 'subsample': 0.8038055922277739, 'colsample_bytree': 0.9697360626828522, 'num_leaves': 50, 'max_bin': 213, 'reg_alpha': 0.9165276180627888, 'reg_lambda': 0.6978746419958803, 'n_estimators': 392}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:36,503] Trial 30 finished with value: 0.4398652165277348 and parameters: {'learning_rate': 0.05283903900606446, 'min_child_weight': 5, 'min_child_samples': 43, 'subsample': 0.5017428359527927, 'colsample_bytree': 0.828198845772347, 'num_leaves': 19, 'max_bin': 263, 'reg_alpha': 0.7031381676404088, 'reg_lambda': 0.9097951122578898, 'n_estimators': 265}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:36,693] Trial 15 finished with value: 0.45531368640664316 and parameters: {'learning_rate': 0.04446841200710032, 'min_child_weight': 2, 'min_child_samples': 84, 'subsample': 0.6533425154037553, 'colsample_bytree': 0.820363118304539, 'num_leaves': 157, 'max_bin': 473, 'reg_alpha': 0.6417854450220529, 'reg_lambda': 0.47239829288193036, 'n_estimators': 200}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:37,168] Trial 34 finished with value: 0.4534363743809908 and parameters: {'learning_rate': 0.06071538151905449, 'min_child_weight': 4, 'min_child_samples': 10, 'subsample': 0.6527204065189184, 'colsample_bytree': 0.6836317372625043, 'num_leaves': 2, 'max_bin': 311, 'reg_alpha': 0.9847993711995322, 'reg_lambda': 0.7857975931913717, 'n_estimators': 486}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:37,251] Trial 5 finished with value: 0.4739619273685493 and parameters: {'learning_rate': 0.07752128897439692, 'min_child_weight': 3, 'min_child_samples': 25, 'subsample': 0.5950525828515674, 'colsample_bytree': 0.7730746646587934, 'num_leaves': 176, 'max_bin': 436, 'reg_alpha': 0.32076521524738855, 'reg_lambda': 0.2656925509398469, 'n_estimators': 135}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:37,534] Trial 35 finished with value: 0.4609987339594277 and parameters: {'learning_rate': 0.031516999777292484, 'min_child_weight': 3, 'min_child_samples': 21, 'subsample': 0.511099817290552, 'colsample_bytree': 0.6901171155920378, 'num_leaves': 2, 'max_bin': 292, 'reg_alpha': 0.831872305763177, 'reg_lambda': 0.9909812306778146, 'n_estimators': 300}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:38,113] Trial 24 finished with value: 0.45098990393488614 and parameters: {'learning_rate': 0.04575085362804545, 'min_child_weight': 3, 'min_child_samples': 13, 'subsample': 0.7541680880961736, 'colsample_bytree': 0.7145450477670267, 'num_leaves': 67, 'max_bin': 360, 'reg_alpha': 0.10947606785288466, 'reg_lambda': 0.9706402934200427, 'n_estimators': 310}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:38,273] Trial 25 finished with value: 0.4648167973480826 and parameters: {'learning_rate': 0.0890831808292845, 'min_child_weight': 7, 'min_child_samples': 9, 'subsample': 0.5516006978788226, 'colsample_bytree': 0.7170864644018446, 'num_leaves': 112, 'max_bin': 482, 'reg_alpha': 0.1940994202272469, 'reg_lambda': 0.019561734315171386, 'n_estimators': 129}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:38,745] Trial 18 finished with value: 0.5000993416705153 and parameters: {'learning_rate': 0.09068129632719696, 'min_child_weight': 5, 'min_child_samples': 26, 'subsample': 0.6243601581903377, 'colsample_bytree': 0.8951002626089792, 'num_leaves': 91, 'max_bin': 232, 'reg_alpha': 0.14625364595116686, 'reg_lambda': 0.9442049044597767, 'n_estimators': 294}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:39,203] Trial 0 finished with value: 0.4757718974228844 and parameters: {'learning_rate': 0.09097528550416252, 'min_child_weight': 5, 'min_child_samples': 71, 'subsample': 0.5231210133646346, 'colsample_bytree': 0.5759234898016805, 'num_leaves': 194, 'max_bin': 406, 'reg_alpha': 0.37236977009984984, 'reg_lambda': 0.6896755220041527, 'n_estimators': 202}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:39,742] Trial 4 finished with value: 0.48381005892643075 and parameters: {'learning_rate': 0.08233951224300588, 'min_child_weight': 7, 'min_child_samples': 16, 'subsample': 0.9650732135604705, 'colsample_bytree': 0.9245654611339252, 'num_leaves': 210, 'max_bin': 473, 'reg_alpha': 0.8937686282777231, 'reg_lambda': 0.4538654072513326, 'n_estimators': 155}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:39,882] Trial 22 finished with value: 0.46171321821149974 and parameters: {'learning_rate': 0.04244549917613283, 'min_child_weight': 4, 'min_child_samples': 47, 'subsample': 0.8103546747541431, 'colsample_bytree': 0.7938042924821134, 'num_leaves': 83, 'max_bin': 423, 'reg_alpha': 0.2496827174098255, 'reg_lambda': 0.9346817869466422, 'n_estimators': 366}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:40,259] Trial 1 finished with value: 0.4794639482949669 and parameters: {'learning_rate': 0.07236228639781968, 'min_child_weight': 3, 'min_child_samples': 19, 'subsample': 0.5167842102903091, 'colsample_bytree': 0.6615253885770753, 'num_leaves': 68, 'max_bin': 231, 'reg_alpha': 0.17722270380278238, 'reg_lambda': 0.5838724923239891, 'n_estimators': 415}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:40,521] Trial 36 finished with value: 0.4372729543279935 and parameters: {'learning_rate': 0.03249544764750561, 'min_child_weight': 5, 'min_child_samples': 27, 'subsample': 0.7091359921050925, 'colsample_bytree': 0.6591793924598602, 'num_leaves': 24, 'max_bin': 284, 'reg_alpha': 0.7950518497757999, 'reg_lambda': 0.6367031566405922, 'n_estimators': 289}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:40,794] Trial 8 finished with value: 0.4956185095542902 and parameters: {'learning_rate': 0.09357057004455098, 'min_child_weight': 4, 'min_child_samples': 100, 'subsample': 0.5073062688926274, 'colsample_bytree': 0.6199970155849936, 'num_leaves': 223, 'max_bin': 371, 'reg_alpha': 0.015324083434789193, 'reg_lambda': 0.12135010811891944, 'n_estimators': 287}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:41,605] Trial 32 finished with value: 0.4594193914283173 and parameters: {'learning_rate': 0.0862461258013705, 'min_child_weight': 1, 'min_child_samples': 99, 'subsample': 0.7212974365056544, 'colsample_bytree': 0.750986178843601, 'num_leaves': 70, 'max_bin': 465, 'reg_alpha': 0.9448375051338788, 'reg_lambda': 0.39349731653975983, 'n_estimators': 203}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:42,375] Trial 26 finished with value: 0.43981428217985635 and parameters: {'learning_rate': 0.014796723258549915, 'min_child_weight': 5, 'min_child_samples': 27, 'subsample': 0.9992987734619673, 'colsample_bytree': 0.8639943801380652, 'num_leaves': 47, 'max_bin': 302, 'reg_alpha': 0.6265431043799838, 'reg_lambda': 0.3794571960755827, 'n_estimators': 473}. Best is trial 23 with value: 0.4362609542369093.
# [I 2021-09-30 10:20:42,593] Trial 40 finished with value: 0.43497036990241844 and parameters: {'learning_rate': 0.012348491939450652, 'min_child_weight': 5, 'min_child_samples': 69, 'subsample': 0.709155921341359, 'colsample_bytree': 0.6320337721597308, 'num_leaves': 21, 'max_bin': 383, 'reg_alpha': 0.7023794069389976, 'reg_lambda': 0.6309438203556171, 'n_estimators': 382}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:43,404] Trial 31 finished with value: 0.4663777820697495 and parameters: {'learning_rate': 0.06796496760001346, 'min_child_weight': 4, 'min_child_samples': 83, 'subsample': 0.9799028759285782, 'colsample_bytree': 0.7252928901296831, 'num_leaves': 46, 'max_bin': 300, 'reg_alpha': 0.06706263685399971, 'reg_lambda': 0.8115751850641922, 'n_estimators': 454}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:43,516] Trial 41 finished with value: 0.4380331225061013 and parameters: {'learning_rate': 0.02850943053537953, 'min_child_weight': 6, 'min_child_samples': 36, 'subsample': 0.7209388114307062, 'colsample_bytree': 0.6328539613872485, 'num_leaves': 23, 'max_bin': 276, 'reg_alpha': 0.7049916577444666, 'reg_lambda': 0.8435342198490321, 'n_estimators': 385}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:43,622] Trial 39 finished with value: 0.43520141853837246 and parameters: {'learning_rate': 0.013670315498256523, 'min_child_weight': 5, 'min_child_samples': 32, 'subsample': 0.6997999812633617, 'colsample_bytree': 0.6176242174669387, 'num_leaves': 27, 'max_bin': 380, 'reg_alpha': 0.6958549596982195, 'reg_lambda': 0.6378089705201695, 'n_estimators': 387}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:43,778] Trial 42 finished with value: 0.43511854353561263 and parameters: {'learning_rate': 0.011583182348372897, 'min_child_weight': 6, 'min_child_samples': 34, 'subsample': 0.6973677111231065, 'colsample_bytree': 0.628812818676959, 'num_leaves': 20, 'max_bin': 270, 'reg_alpha': 0.6967366637859984, 'reg_lambda': 0.8217118731736032, 'n_estimators': 391}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:43,821] Trial 45 finished with value: 0.4361059935431884 and parameters: {'learning_rate': 0.027811266988244373, 'min_child_weight': 5, 'min_child_samples': 33, 'subsample': 0.6954805661925793, 'colsample_bytree': 0.6295956370464237, 'num_leaves': 27, 'max_bin': 272, 'reg_alpha': 0.6981961721450456, 'reg_lambda': 0.8053904552288165, 'n_estimators': 244}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:44,008] Trial 43 finished with value: 0.43516008180588406 and parameters: {'learning_rate': 0.011549122025227565, 'min_child_weight': 6, 'min_child_samples': 30, 'subsample': 0.7032075919896615, 'colsample_bytree': 0.6250339787688454, 'num_leaves': 17, 'max_bin': 270, 'reg_alpha': 0.6902006520058938, 'reg_lambda': 0.8302796786394977, 'n_estimators': 457}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:44,360] Trial 46 finished with value: 0.4363070790386194 and parameters: {'learning_rate': 0.027774998343851342, 'min_child_weight': 6, 'min_child_samples': 33, 'subsample': 0.6998813594884714, 'colsample_bytree': 0.6397393516862736, 'num_leaves': 27, 'max_bin': 278, 'reg_alpha': 0.7175816012382161, 'reg_lambda': 0.8362849130915259, 'n_estimators': 261}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:44,837] Trial 13 finished with value: 0.4473467765855077 and parameters: {'learning_rate': 0.017331108572315974, 'min_child_weight': 3, 'min_child_samples': 74, 'subsample': 0.9926714620020683, 'colsample_bytree': 0.8181938189027163, 'num_leaves': 167, 'max_bin': 415, 'reg_alpha': 0.3451114557355133, 'reg_lambda': 0.1685439714402387, 'n_estimators': 314}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:44,958] Trial 47 finished with value: 0.4365242419323625 and parameters: {'learning_rate': 0.02783009347304477, 'min_child_weight': 6, 'min_child_samples': 34, 'subsample': 0.6833120436883887, 'colsample_bytree': 0.6416044654367284, 'num_leaves': 26, 'max_bin': 272, 'reg_alpha': 0.7467159365445613, 'reg_lambda': 0.8099630020192229, 'n_estimators': 242}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:46,592] Trial 12 finished with value: 0.45711063319949613 and parameters: {'learning_rate': 0.026407315931886124, 'min_child_weight': 7, 'min_child_samples': 88, 'subsample': 0.9412109196939373, 'colsample_bytree': 0.7841763530606887, 'num_leaves': 110, 'max_bin': 301, 'reg_alpha': 0.9394915270311966, 'reg_lambda': 0.7660603392746128, 'n_estimators': 459}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:47,940] Trial 50 finished with value: 0.4365868919826754 and parameters: {'learning_rate': 0.026948980883136638, 'min_child_weight': 6, 'min_child_samples': 35, 'subsample': 0.7189437071277259, 'colsample_bytree': 0.6417844737260266, 'num_leaves': 27, 'max_bin': 393, 'reg_alpha': 0.8104000134819247, 'reg_lambda': 0.619527580527006, 'n_estimators': 344}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:48,206] Trial 51 finished with value: 0.4361457114979847 and parameters: {'learning_rate': 0.023561914410656276, 'min_child_weight': 6, 'min_child_samples': 56, 'subsample': 0.6686905081136288, 'colsample_bytree': 0.5327777251918974, 'num_leaves': 26, 'max_bin': 330, 'reg_alpha': 0.8209977211554066, 'reg_lambda': 0.6543378012443376, 'n_estimators': 338}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:48,489] Trial 9 finished with value: 0.49880485112571854 and parameters: {'learning_rate': 0.09310171744661667, 'min_child_weight': 2, 'min_child_samples': 84, 'subsample': 0.6911598903785124, 'colsample_bytree': 0.5372366873836145, 'num_leaves': 209, 'max_bin': 246, 'reg_alpha': 0.8189697653256174, 'reg_lambda': 0.5830485159444802, 'n_estimators': 410}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:48,901] Trial 48 finished with value: 0.43558727642652395 and parameters: {'learning_rate': 0.010111128905449171, 'min_child_weight': 6, 'min_child_samples': 31, 'subsample': 0.6821557665825326, 'colsample_bytree': 0.6310218961014109, 'num_leaves': 27, 'max_bin': 288, 'reg_alpha': 0.8211151239278867, 'reg_lambda': 0.600657060806099, 'n_estimators': 487}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:48,963] Trial 49 finished with value: 0.4391168364310811 and parameters: {'learning_rate': 0.02587639261309271, 'min_child_weight': 6, 'min_child_samples': 32, 'subsample': 0.6900005221550352, 'colsample_bytree': 0.5324273542229747, 'num_leaves': 26, 'max_bin': 273, 'reg_alpha': 0.8270079662699377, 'reg_lambda': 0.6006039958933695, 'n_estimators': 436}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:49,418] Trial 54 finished with value: 0.43650449981701633 and parameters: {'learning_rate': 0.010495920899404895, 'min_child_weight': 6, 'min_child_samples': 56, 'subsample': 0.7641007423034831, 'colsample_bytree': 0.5469594380469782, 'num_leaves': 30, 'max_bin': 382, 'reg_alpha': 0.5576430577312972, 'reg_lambda': 0.7191617421003155, 'n_estimators': 336}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:51,020] Trial 27 finished with value: 0.46808276974247714 and parameters: {'learning_rate': 0.04324065473952543, 'min_child_weight': 1, 'min_child_samples': 60, 'subsample': 0.9231685147124934, 'colsample_bytree': 0.5935960052593031, 'num_leaves': 221, 'max_bin': 330, 'reg_alpha': 0.4291703954581204, 'reg_lambda': 0.38547986733602313, 'n_estimators': 284}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:52,627] Trial 28 finished with value: 0.46389671561998685 and parameters: {'learning_rate': 0.03722979560144881, 'min_child_weight': 2, 'min_child_samples': 36, 'subsample': 0.9517285646858962, 'colsample_bytree': 0.6389357820898951, 'num_leaves': 192, 'max_bin': 231, 'reg_alpha': 0.21694564215424306, 'reg_lambda': 0.4671043355451405, 'n_estimators': 239}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:53,447] Trial 44 finished with value: 0.44070485796839165 and parameters: {'learning_rate': 0.013143170878630584, 'min_child_weight': 6, 'min_child_samples': 33, 'subsample': 0.7091290752784641, 'colsample_bytree': 0.8329083294738445, 'num_leaves': 147, 'max_bin': 278, 'reg_alpha': 0.7273710154131902, 'reg_lambda': 0.8237307128161733, 'n_estimators': 244}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:54,124] Trial 29 finished with value: 0.5061323499268776 and parameters: {'learning_rate': 0.07721857725438151, 'min_child_weight': 1, 'min_child_samples': 36, 'subsample': 0.818314450318052, 'colsample_bytree': 0.5699297778772846, 'num_leaves': 130, 'max_bin': 220, 'reg_alpha': 0.4609702553573015, 'reg_lambda': 0.04302560699750191, 'n_estimators': 350}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:54,793] Trial 37 finished with value: 0.4747120122672135 and parameters: {'learning_rate': 0.04901225663261113, 'min_child_weight': 5, 'min_child_samples': 68, 'subsample': 0.721406720025401, 'colsample_bytree': 0.6860067311513846, 'num_leaves': 109, 'max_bin': 374, 'reg_alpha': 0.7442853302100335, 'reg_lambda': 0.6450009896589882, 'n_estimators': 392}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:55,072] Trial 38 finished with value: 0.4401144616936754 and parameters: {'learning_rate': 0.012810920143303971, 'min_child_weight': 5, 'min_child_samples': 68, 'subsample': 0.6581182196574392, 'colsample_bytree': 0.6167794366826995, 'num_leaves': 116, 'max_bin': 373, 'reg_alpha': 0.7020057818545236, 'reg_lambda': 0.6399158934462053, 'n_estimators': 387}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:55,117] Trial 3 finished with value: 0.5023643278170606 and parameters: {'learning_rate': 0.04259427344153876, 'min_child_weight': 4, 'min_child_samples': 31, 'subsample': 0.5397771651677346, 'colsample_bytree': 0.9643234148787624, 'num_leaves': 194, 'max_bin': 207, 'reg_alpha': 0.14552262391557025, 'reg_lambda': 0.7724044628655264, 'n_estimators': 345}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:55,228] Trial 67 finished with value: 0.43603151517818073 and parameters: {'learning_rate': 0.019251116582880763, 'min_child_weight': 5, 'min_child_samples': 19, 'subsample': 0.617800298574682, 'colsample_bytree': 0.5822688409195281, 'num_leaves': 12, 'max_bin': 349, 'reg_alpha': 0.6216312162845155, 'reg_lambda': 0.531258409831848, 'n_estimators': 428}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:55,863] Trial 6 finished with value: 0.5647630028856039 and parameters: {'learning_rate': 0.09413475862795527, 'min_child_weight': 1, 'min_child_samples': 53, 'subsample': 0.7816559608583569, 'colsample_bytree': 0.8677512126991493, 'num_leaves': 169, 'max_bin': 452, 'reg_alpha': 0.7589873213963618, 'reg_lambda': 0.648263318120972, 'n_estimators': 446}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:56,633] Trial 63 finished with value: 0.43964403448491873 and parameters: {'learning_rate': 0.019431713217485054, 'min_child_weight': 5, 'min_child_samples': 68, 'subsample': 0.7636663771519767, 'colsample_bytree': 0.5808166889647901, 'num_leaves': 39, 'max_bin': 393, 'reg_alpha': 0.5267812782011811, 'reg_lambda': 0.5384014888671234, 'n_estimators': 443}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:56,962] Trial 59 finished with value: 0.43706822455666783 and parameters: {'learning_rate': 0.010092540194193153, 'min_child_weight': 6, 'min_child_samples': 58, 'subsample': 0.7622338627342388, 'colsample_bytree': 0.538730423311506, 'num_leaves': 60, 'max_bin': 394, 'reg_alpha': 0.5053327852494639, 'reg_lambda': 0.547462094404189, 'n_estimators': 351}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:57,076] Trial 65 finished with value: 0.43876531198731356 and parameters: {'learning_rate': 0.01793334061457024, 'min_child_weight': 5, 'min_child_samples': 19, 'subsample': 0.618757435784891, 'colsample_bytree': 0.589542691386492, 'num_leaves': 40, 'max_bin': 335, 'reg_alpha': 0.622852480833206, 'reg_lambda': 0.5549844428527847, 'n_estimators': 430}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:58,139] Trial 21 finished with value: 0.5490373722007166 and parameters: {'learning_rate': 0.09861940676767775, 'min_child_weight': 1, 'min_child_samples': 15, 'subsample': 0.7893992209733826, 'colsample_bytree': 0.6645404720623119, 'num_leaves': 167, 'max_bin': 397, 'reg_alpha': 0.6916448328873073, 'reg_lambda': 0.8874806079732879, 'n_estimators': 418}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:58,772] Trial 61 finished with value: 0.4403636703933072 and parameters: {'learning_rate': 0.017866025886139378, 'min_child_weight': 5, 'min_child_samples': 66, 'subsample': 0.7622424818286888, 'colsample_bytree': 0.5620272007638432, 'num_leaves': 60, 'max_bin': 390, 'reg_alpha': 0.5084143036784357, 'reg_lambda': 0.5493605801397656, 'n_estimators': 415}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:59,413] Trial 76 finished with value: 0.43646208552988097 and parameters: {'learning_rate': 0.017072380044375238, 'min_child_weight': 5, 'min_child_samples': 22, 'subsample': 0.6289299419118608, 'colsample_bytree': 0.6092538760968118, 'num_leaves': 11, 'max_bin': 354, 'reg_alpha': 0.6399384248451376, 'reg_lambda': 0.6975545171977602, 'n_estimators': 427}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:20:59,907] Trial 62 finished with value: 0.43780588212981286 and parameters: {'learning_rate': 0.011829837272221241, 'min_child_weight': 5, 'min_child_samples': 69, 'subsample': 0.7671172137769098, 'colsample_bytree': 0.5834822538672103, 'num_leaves': 58, 'max_bin': 388, 'reg_alpha': 0.5394269512147312, 'reg_lambda': 0.5361817692894084, 'n_estimators': 435}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:00,379] Trial 77 finished with value: 0.4360066799046425 and parameters: {'learning_rate': 0.015922473034094227, 'min_child_weight': 7, 'min_child_samples': 16, 'subsample': 0.6307579690141661, 'colsample_bytree': 0.6125737618039933, 'num_leaves': 13, 'max_bin': 248, 'reg_alpha': 0.6525171070672536, 'reg_lambda': 0.7288468408011004, 'n_estimators': 492}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:00,695] Trial 53 finished with value: 0.44276728525009884 and parameters: {'learning_rate': 0.018889559305601086, 'min_child_weight': 6, 'min_child_samples': 72, 'subsample': 0.7686102795831585, 'colsample_bytree': 0.5443198151652784, 'num_leaves': 118, 'max_bin': 383, 'reg_alpha': 0.488261289636106, 'reg_lambda': 0.6945780268341935, 'n_estimators': 337}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:01,312] Trial 56 finished with value: 0.4426999721483922 and parameters: {'learning_rate': 0.017941362992498593, 'min_child_weight': 6, 'min_child_samples': 71, 'subsample': 0.765957241155134, 'colsample_bytree': 0.5451800406963097, 'num_leaves': 120, 'max_bin': 387, 'reg_alpha': 0.5199182347233071, 'reg_lambda': 0.6147746894525641, 'n_estimators': 342}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:01,912] Trial 64 finished with value: 0.4370681704280487 and parameters: {'learning_rate': 0.010065051742967662, 'min_child_weight': 5, 'min_child_samples': 19, 'subsample': 0.7602341835281192, 'colsample_bytree': 0.5823896701061886, 'num_leaves': 56, 'max_bin': 387, 'reg_alpha': 0.563929488068867, 'reg_lambda': 0.5251567340177742, 'n_estimators': 499}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:02,075] Trial 78 finished with value: 0.43551748023006925 and parameters: {'learning_rate': 0.016024363438825892, 'min_child_weight': 7, 'min_child_samples': 22, 'subsample': 0.625488980015356, 'colsample_bytree': 0.6126604699555671, 'num_leaves': 15, 'max_bin': 250, 'reg_alpha': 0.5863092413558072, 'reg_lambda': 0.7262104788371238, 'n_estimators': 471}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:02,237] Trial 79 finished with value: 0.4359365631749697 and parameters: {'learning_rate': 0.015227450648199421, 'min_child_weight': 6, 'min_child_samples': 5, 'subsample': 0.6234163527464142, 'colsample_bytree': 0.6146512201620958, 'num_leaves': 14, 'max_bin': 244, 'reg_alpha': 0.5928099543519443, 'reg_lambda': 0.6996996113256525, 'n_estimators': 473}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:02,425] Trial 57 finished with value: 0.4435222346395659 and parameters: {'learning_rate': 0.01937183113504168, 'min_child_weight': 6, 'min_child_samples': 54, 'subsample': 0.7624324644227886, 'colsample_bytree': 0.5427396175525577, 'num_leaves': 106, 'max_bin': 381, 'reg_alpha': 0.5243648925203062, 'reg_lambda': 0.5816251817905036, 'n_estimators': 354}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:02,946] Trial 55 finished with value: 0.4386278838879018 and parameters: {'learning_rate': 0.010300802076690832, 'min_child_weight': 6, 'min_child_samples': 55, 'subsample': 0.7574569456090504, 'colsample_bytree': 0.5417445462309127, 'num_leaves': 128, 'max_bin': 387, 'reg_alpha': 0.5444014577894997, 'reg_lambda': 0.6835171526984705, 'n_estimators': 345}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:03,069] Trial 66 finished with value: 0.44092096764832045 and parameters: {'learning_rate': 0.018149494505795512, 'min_child_weight': 5, 'min_child_samples': 68, 'subsample': 0.6218193386283906, 'colsample_bytree': 0.5742246843682196, 'num_leaves': 57, 'max_bin': 360, 'reg_alpha': 0.6148217502587761, 'reg_lambda': 0.5758965106244216, 'n_estimators': 437}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:03,135] Trial 80 finished with value: 0.43749773484558313 and parameters: {'learning_rate': 0.022381131019712817, 'min_child_weight': 7, 'min_child_samples': 76, 'subsample': 0.7391074454114868, 'colsample_bytree': 0.663929777975614, 'num_leaves': 15, 'max_bin': 252, 'reg_alpha': 0.5885170159330311, 'reg_lambda': 0.420381370466994, 'n_estimators': 487}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:03,390] Trial 81 finished with value: 0.4362241716042605 and parameters: {'learning_rate': 0.0216824251269275, 'min_child_weight': 7, 'min_child_samples': 75, 'subsample': 0.7400010890391129, 'colsample_bytree': 0.5044956655767592, 'num_leaves': 11, 'max_bin': 251, 'reg_alpha': 0.869324999887349, 'reg_lambda': 0.7500589919581514, 'n_estimators': 497}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:03,542] Trial 58 finished with value: 0.4386834680829087 and parameters: {'learning_rate': 0.010640695227211179, 'min_child_weight': 6, 'min_child_samples': 53, 'subsample': 0.7653951432239632, 'colsample_bytree': 0.5360102726076863, 'num_leaves': 131, 'max_bin': 388, 'reg_alpha': 0.5762257253094288, 'reg_lambda': 0.6200990045994272, 'n_estimators': 347}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:04,063] Trial 82 finished with value: 0.43593967508347975 and parameters: {'learning_rate': 0.015310275717130627, 'min_child_weight': 7, 'min_child_samples': 77, 'subsample': 0.5823204033088262, 'colsample_bytree': 0.9947741866688656, 'num_leaves': 15, 'max_bin': 242, 'reg_alpha': 0.8747179337247881, 'reg_lambda': 0.7497326334807077, 'n_estimators': 498}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:04,297] Trial 52 finished with value: 0.4440940753212444 and parameters: {'learning_rate': 0.018713265459883506, 'min_child_weight': 6, 'min_child_samples': 55, 'subsample': 0.6722623982986785, 'colsample_bytree': 0.5502893922828166, 'num_leaves': 131, 'max_bin': 385, 'reg_alpha': 0.5029352844876332, 'reg_lambda': 0.6910488005723265, 'n_estimators': 345}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:04,644] Trial 71 finished with value: 0.439082971235282 and parameters: {'learning_rate': 0.01775125568144895, 'min_child_weight': 5, 'min_child_samples': 20, 'subsample': 0.6201812547097386, 'colsample_bytree': 0.5951693947075022, 'num_leaves': 39, 'max_bin': 347, 'reg_alpha': 0.6134152859807528, 'reg_lambda': 0.5485129950318092, 'n_estimators': 495}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:05,473] Trial 84 finished with value: 0.43720827641807053 and parameters: {'learning_rate': 0.022352794949680135, 'min_child_weight': 7, 'min_child_samples': 29, 'subsample': 0.6000911821452557, 'colsample_bytree': 0.6633856034917962, 'num_leaves': 16, 'max_bin': 256, 'reg_alpha': 0.5954974795968184, 'reg_lambda': 0.7449812379189354, 'n_estimators': 500}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:05,534] Trial 85 finished with value: 0.4365537572861784 and parameters: {'learning_rate': 0.022315199200863618, 'min_child_weight': 7, 'min_child_samples': 6, 'subsample': 0.589474805836162, 'colsample_bytree': 0.6619869856141009, 'num_leaves': 15, 'max_bin': 250, 'reg_alpha': 0.6640373362904634, 'reg_lambda': 0.7385474524706743, 'n_estimators': 470}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:05,625] Trial 86 finished with value: 0.4364432749698407 and parameters: {'learning_rate': 0.02267481989759558, 'min_child_weight': 7, 'min_child_samples': 29, 'subsample': 0.637436821215749, 'colsample_bytree': 0.6064406828428773, 'num_leaves': 13, 'max_bin': 244, 'reg_alpha': 0.8681140720737698, 'reg_lambda': 0.8715745508918191, 'n_estimators': 466}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:06,074] Trial 97 finished with value: 0.46430808692382086 and parameters: {'learning_rate': 0.014365630688137225, 'min_child_weight': 7, 'min_child_samples': 5, 'subsample': 0.5675667794791779, 'colsample_bytree': 0.9361406287971633, 'num_leaves': 2, 'max_bin': 237, 'reg_alpha': 0.6672406917782033, 'reg_lambda': 0.8770882407109785, 'n_estimators': 470}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:06,548] Trial 69 finished with value: 0.4418054424069996 and parameters: {'learning_rate': 0.01879242161795298, 'min_child_weight': 5, 'min_child_samples': 19, 'subsample': 0.7752396415388947, 'colsample_bytree': 0.6043051655848335, 'num_leaves': 58, 'max_bin': 351, 'reg_alpha': 0.6440074876443005, 'reg_lambda': 0.5369954173464182, 'n_estimators': 433}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:06,633] Trial 99 finished with value: 0.44143866494725337 and parameters: {'learning_rate': 0.014333267208459103, 'min_child_weight': 4, 'min_child_samples': 40, 'subsample': 0.568809004848432, 'colsample_bytree': 0.7031391176321529, 'num_leaves': 4, 'max_bin': 210, 'reg_alpha': 0.782109570565611, 'reg_lambda': 0.863361323342826, 'n_estimators': 453}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:06,980] Trial 33 finished with value: 0.4721353853310337 and parameters: {'learning_rate': 0.0323415180779945, 'min_child_weight': 2, 'min_child_samples': 10, 'subsample': 0.6920312549918226, 'colsample_bytree': 0.6791067561237765, 'num_leaves': 133, 'max_bin': 342, 'reg_alpha': 0.9585121714269587, 'reg_lambda': 0.24265242210473448, 'n_estimators': 499}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:07,755] Trial 19 finished with value: 0.5215979032114578 and parameters: {'learning_rate': 0.047735257254201066, 'min_child_weight': 6, 'min_child_samples': 9, 'subsample': 0.9337106565585078, 'colsample_bytree': 0.8134950641806714, 'num_leaves': 193, 'max_bin': 302, 'reg_alpha': 0.4213901005807814, 'reg_lambda': 0.6440890113141745, 'n_estimators': 467}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:07,888] Trial 73 finished with value: 0.4405742263609861 and parameters: {'learning_rate': 0.016880344418815106, 'min_child_weight': 7, 'min_child_samples': 50, 'subsample': 0.7786851918978438, 'colsample_bytree': 0.6068908243098147, 'num_leaves': 56, 'max_bin': 398, 'reg_alpha': 0.8736447987052451, 'reg_lambda': 0.5245415462102194, 'n_estimators': 447}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:08,058] Trial 101 finished with value: 0.43914689026284415 and parameters: {'learning_rate': 0.01457870139932643, 'min_child_weight': 4, 'min_child_samples': 40, 'subsample': 0.6455569331210683, 'colsample_bytree': 0.621215043090203, 'num_leaves': 5, 'max_bin': 205, 'reg_alpha': 0.7937794364158706, 'reg_lambda': 0.6668586574839596, 'n_estimators': 453}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:08,345] Trial 68 finished with value: 0.44220972542866416 and parameters: {'learning_rate': 0.018751817985587727, 'min_child_weight': 5, 'min_child_samples': 67, 'subsample': 0.6156888967150991, 'colsample_bytree': 0.5709171302973333, 'num_leaves': 56, 'max_bin': 349, 'reg_alpha': 0.6357526208613707, 'reg_lambda': 0.541984086342625, 'n_estimators': 499}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:09,052] Trial 74 finished with value: 0.4408169099564615 and parameters: {'learning_rate': 0.018478416981230577, 'min_child_weight': 5, 'min_child_samples': 17, 'subsample': 0.6173772924291435, 'colsample_bytree': 0.5956070276208557, 'num_leaves': 61, 'max_bin': 355, 'reg_alpha': 0.6390458720290073, 'reg_lambda': 0.5475706473044647, 'n_estimators': 428}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:09,812] Trial 70 finished with value: 0.4400270808568988 and parameters: {'learning_rate': 0.018462271460429423, 'min_child_weight': 5, 'min_child_samples': 23, 'subsample': 0.7794133963913513, 'colsample_bytree': 0.5766409938421186, 'num_leaves': 60, 'max_bin': 352, 'reg_alpha': 0.6306359028686429, 'reg_lambda': 0.5560944465921609, 'n_estimators': 436}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:10,155] Trial 83 finished with value: 0.441126096803626 and parameters: {'learning_rate': 0.02270074963275361, 'min_child_weight': 7, 'min_child_samples': 50, 'subsample': 0.593136203947821, 'colsample_bytree': 0.6031328555653734, 'num_leaves': 37, 'max_bin': 250, 'reg_alpha': 0.8763224406919315, 'reg_lambda': 0.7460897360750472, 'n_estimators': 498}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:10,351] Trial 72 finished with value: 0.4435333020096156 and parameters: {'learning_rate': 0.019977777170586998, 'min_child_weight': 5, 'min_child_samples': 19, 'subsample': 0.777967592359923, 'colsample_bytree': 0.594235411685287, 'num_leaves': 58, 'max_bin': 346, 'reg_alpha': 0.651117353402049, 'reg_lambda': 0.546300250859177, 'n_estimators': 499}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:10,426] Trial 75 finished with value: 0.4400853513592617 and parameters: {'learning_rate': 0.01701525966186606, 'min_child_weight': 5, 'min_child_samples': 19, 'subsample': 0.628718463164545, 'colsample_bytree': 0.606910605133345, 'num_leaves': 61, 'max_bin': 353, 'reg_alpha': 0.634790392470453, 'reg_lambda': 0.5439741242550501, 'n_estimators': 425}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:10,598] Trial 87 finished with value: 0.44072823636083946 and parameters: {'learning_rate': 0.022685717814529237, 'min_child_weight': 7, 'min_child_samples': 48, 'subsample': 0.5835692696469652, 'colsample_bytree': 0.6637128628636126, 'num_leaves': 37, 'max_bin': 203, 'reg_alpha': 0.601704813876207, 'reg_lambda': 0.8836498823770196, 'n_estimators': 476}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:11,292] Trial 88 finished with value: 0.4401489725848508 and parameters: {'learning_rate': 0.021778604343319068, 'min_child_weight': 7, 'min_child_samples': 29, 'subsample': 0.5818818872776402, 'colsample_bytree': 0.6660556958345109, 'num_leaves': 37, 'max_bin': 204, 'reg_alpha': 0.5829177646188035, 'reg_lambda': 0.8735529538800135, 'n_estimators': 469}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:11,486] Trial 90 finished with value: 0.4411056161572593 and parameters: {'learning_rate': 0.02241274356919827, 'min_child_weight': 7, 'min_child_samples': 49, 'subsample': 0.5989827167075836, 'colsample_bytree': 0.6641232456584464, 'num_leaves': 39, 'max_bin': 254, 'reg_alpha': 0.5934346333249987, 'reg_lambda': 0.8578981449512582, 'n_estimators': 468}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:11,815] Trial 89 finished with value: 0.4379133076368978 and parameters: {'learning_rate': 0.014379779473588518, 'min_child_weight': 7, 'min_child_samples': 7, 'subsample': 0.5799076789737507, 'colsample_bytree': 0.9989481597533627, 'num_leaves': 36, 'max_bin': 254, 'reg_alpha': 0.5871300799637504, 'reg_lambda': 0.7414700912127973, 'n_estimators': 478}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:12,052] Trial 91 finished with value: 0.438329060348879 and parameters: {'learning_rate': 0.014907110717439572, 'min_child_weight': 7, 'min_child_samples': 29, 'subsample': 0.6717998016020144, 'colsample_bytree': 0.9939346265591998, 'num_leaves': 37, 'max_bin': 241, 'reg_alpha': 0.8763744074919977, 'reg_lambda': 0.7555883948140031, 'n_estimators': 467}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:12,822] Trial 92 finished with value: 0.4376016395203367 and parameters: {'learning_rate': 0.01421360933727498, 'min_child_weight': 7, 'min_child_samples': 39, 'subsample': 0.5800342851208339, 'colsample_bytree': 0.6002262215656449, 'num_leaves': 37, 'max_bin': 200, 'reg_alpha': 0.6652362768500807, 'reg_lambda': 0.8684444882911736, 'n_estimators': 470}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:13,112] Trial 96 finished with value: 0.43815649452735983 and parameters: {'learning_rate': 0.014179183455144352, 'min_child_weight': 7, 'min_child_samples': 5, 'subsample': 0.5830452957470271, 'colsample_bytree': 0.9279333539032159, 'num_leaves': 37, 'max_bin': 239, 'reg_alpha': 0.667855874453289, 'reg_lambda': 0.8835685500181173, 'n_estimators': 470}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:13,193] Trial 94 finished with value: 0.4374760322345236 and parameters: {'learning_rate': 0.015011799653277758, 'min_child_weight': 7, 'min_child_samples': 6, 'subsample': 0.6012135879435297, 'colsample_bytree': 0.6059965942671889, 'num_leaves': 37, 'max_bin': 262, 'reg_alpha': 0.7775603702225585, 'reg_lambda': 0.735346928332717, 'n_estimators': 468}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:13,304] Trial 93 finished with value: 0.4374331992695707 and parameters: {'learning_rate': 0.014137656444869596, 'min_child_weight': 7, 'min_child_samples': 29, 'subsample': 0.5895153829424925, 'colsample_bytree': 0.6530102843270644, 'num_leaves': 40, 'max_bin': 206, 'reg_alpha': 0.7755075436449129, 'reg_lambda': 0.8682834665411255, 'n_estimators': 470}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:13,341] Trial 95 finished with value: 0.43833130482879784 and parameters: {'learning_rate': 0.014497163543544713, 'min_child_weight': 7, 'min_child_samples': 6, 'subsample': 0.5928242773364573, 'colsample_bytree': 0.9819506769316045, 'num_leaves': 37, 'max_bin': 239, 'reg_alpha': 0.7693497991311483, 'reg_lambda': 0.8606986661646092, 'n_estimators': 470}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:13,509] Trial 98 finished with value: 0.4392270061523541 and parameters: {'learning_rate': 0.014656112743554859, 'min_child_weight': 7, 'min_child_samples': 48, 'subsample': 0.569083731565094, 'colsample_bytree': 0.9527658292329729, 'num_leaves': 35, 'max_bin': 205, 'reg_alpha': 0.7806664961113935, 'reg_lambda': 0.8803713696373054, 'n_estimators': 470}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:13,854] Trial 60 finished with value: 0.4394314977059808 and parameters: {'learning_rate': 0.010074370254477326, 'min_child_weight': 5, 'min_child_samples': 56, 'subsample': 0.7474584048591719, 'colsample_bytree': 0.5535826589588425, 'num_leaves': 144, 'max_bin': 334, 'reg_alpha': 0.5775118465921963, 'reg_lambda': 0.5513739572917441, 'n_estimators': 424}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:14,192] Trial 102 finished with value: 0.43625867308338995 and parameters: {'learning_rate': 0.014486953238438897, 'min_child_weight': 7, 'min_child_samples': 48, 'subsample': 0.6438249609134878, 'colsample_bytree': 0.62445572879723, 'num_leaves': 33, 'max_bin': 261, 'reg_alpha': 0.7623846773862226, 'reg_lambda': 0.7831039291627795, 'n_estimators': 403}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:14,330] Trial 100 finished with value: 0.43905331949454424 and parameters: {'learning_rate': 0.014371214565277996, 'min_child_weight': 4, 'min_child_samples': 80, 'subsample': 0.5290566993044912, 'colsample_bytree': 0.9919572618124318, 'num_leaves': 35, 'max_bin': 206, 'reg_alpha': 0.7766615709298864, 'reg_lambda': 0.663949394563836, 'n_estimators': 480}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:14,384] Trial 103 finished with value: 0.43644782890780914 and parameters: {'learning_rate': 0.014900788224415625, 'min_child_weight': 7, 'min_child_samples': 79, 'subsample': 0.6427033932126313, 'colsample_bytree': 0.6268469879837427, 'num_leaves': 33, 'max_bin': 405, 'reg_alpha': 0.7627909054373381, 'reg_lambda': 0.6653032395973445, 'n_estimators': 404}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:15,342] Trial 111 finished with value: 0.43545011641838244 and parameters: {'learning_rate': 0.015221505525244667, 'min_child_weight': 7, 'min_child_samples': 24, 'subsample': 0.524822774379581, 'colsample_bytree': 0.650992761786235, 'num_leaves': 21, 'max_bin': 261, 'reg_alpha': 0.7724012934546596, 'reg_lambda': 0.7776251689531342, 'n_estimators': 403}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:15,698] Trial 114 finished with value: 0.4352236998219599 and parameters: {'learning_rate': 0.014580951822962197, 'min_child_weight': 7, 'min_child_samples': 24, 'subsample': 0.6763223735567763, 'colsample_bytree': 0.622345288966097, 'num_leaves': 18, 'max_bin': 261, 'reg_alpha': 0.6780505816557898, 'reg_lambda': 0.7203034890286033, 'n_estimators': 399}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:15,839] Trial 124 finished with value: 0.4371868578504439 and parameters: {'learning_rate': 0.012223803405561867, 'min_child_weight': 6, 'min_child_samples': 14, 'subsample': 0.7007091676044492, 'colsample_bytree': 0.6186208488485077, 'num_leaves': 8, 'max_bin': 286, 'reg_alpha': 0.7262006901855579, 'reg_lambda': 0.8007445720218466, 'n_estimators': 404}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:16,274] Trial 116 finished with value: 0.43513730760791924 and parameters: {'learning_rate': 0.012280726005425562, 'min_child_weight': 6, 'min_child_samples': 24, 'subsample': 0.6719149272339985, 'colsample_bytree': 0.6246438044232113, 'num_leaves': 19, 'max_bin': 264, 'reg_alpha': 0.6731514901474034, 'reg_lambda': 0.7868440646266758, 'n_estimators': 398}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:16,577] Trial 105 finished with value: 0.43855244187989134 and parameters: {'learning_rate': 0.01539729742063012, 'min_child_weight': 7, 'min_child_samples': 24, 'subsample': 0.6472359417598974, 'colsample_bytree': 0.9851353631568066, 'num_leaves': 35, 'max_bin': 262, 'reg_alpha': 0.7689000582475101, 'reg_lambda': 0.6634953580933607, 'n_estimators': 476}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:16,678] Trial 106 finished with value: 0.437046067413832 and parameters: {'learning_rate': 0.014575537225266928, 'min_child_weight': 7, 'min_child_samples': 23, 'subsample': 0.5263282206787956, 'colsample_bytree': 0.6202525542400115, 'num_leaves': 33, 'max_bin': 261, 'reg_alpha': 0.6717216792858374, 'reg_lambda': 0.7835716219898872, 'n_estimators': 482}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:16,772] Trial 104 finished with value: 0.43785228241474244 and parameters: {'learning_rate': 0.015235732812376047, 'min_child_weight': 7, 'min_child_samples': 79, 'subsample': 0.6395212789621622, 'colsample_bytree': 0.6188336245501884, 'num_leaves': 34, 'max_bin': 263, 'reg_alpha': 0.7750707808345451, 'reg_lambda': 0.6662962234807832, 'n_estimators': 481}. Best is trial 40 with value: 0.43497036990241844.
# [I 2021-09-30 10:21:16,855] Trial 115 finished with value: 0.4359494545406884 and parameters: {'learning_rate': 0.015206557365153745, 'min_child_weight': 6, 'min_child_samples': 13, 'subsample': 0.6768224234635597, 'colsample_bytree': 0.6189719908838925, 'num_leaves': 19, 'max_bin': 263, 'reg_alpha': 0.7584806721153887, 'reg_lambda': 0.7791200042051039, 'n_estimators': 484}. Best is trial 40 with value: 0.43497036990241844.
# ...
# [I 2021-09-30 10:21:58,964] Trial 243 finished with value: 0.43562329219279533 and parameters: {'learning_rate': 0.015342250864064204, 'min_child_weight': 6, 'min_child_samples': 19, 'subsample': 0.6364643693640083, 'colsample_bytree': 0.6168919574210734, 'num_leaves': 26, 'max_bin': 361, 'reg_alpha': 0.10665520189618144, 'reg_lambda': 0.08238312748527567, 'n_estimators': 373}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:21:59,307] Trial 246 finished with value: 0.43590635557532403 and parameters: {'learning_rate': 0.01574774833288636, 'min_child_weight': 3, 'min_child_samples': 15, 'subsample': 0.6382450360102533, 'colsample_bytree': 0.6103080833573303, 'num_leaves': 25, 'max_bin': 365, 'reg_alpha': 0.035230935524904056, 'reg_lambda': 0.05332210643914001, 'n_estimators': 372}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:21:59,608] Trial 190 finished with value: 0.45057058033407815 and parameters: {'learning_rate': 0.016904488829431373, 'min_child_weight': 6, 'min_child_samples': 16, 'subsample': 0.5365876676074858, 'colsample_bytree': 0.6580421127997137, 'num_leaves': 238, 'max_bin': 280, 'reg_alpha': 0.35336447888914524, 'reg_lambda': 0.7627606021216503, 'n_estimators': 320}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:00,044] Trial 217 finished with value: 0.44438415200658127 and parameters: {'learning_rate': 0.013340509571544855, 'min_child_weight': 6, 'min_child_samples': 24, 'subsample': 0.6545394022514858, 'colsample_bytree': 0.6405058650852219, 'num_leaves': 252, 'max_bin': 225, 'reg_alpha': 0.6902515792539337, 'reg_lambda': 0.8923219975719929, 'n_estimators': 370}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:00,726] Trial 215 finished with value: 0.4436933380337438 and parameters: {'learning_rate': 0.013483000552829048, 'min_child_weight': 6, 'min_child_samples': 23, 'subsample': 0.6528074334583012, 'colsample_bytree': 0.6412392641509981, 'num_leaves': 179, 'max_bin': 226, 'reg_alpha': 0.686143395706334, 'reg_lambda': 0.8991104058051417, 'n_estimators': 369}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:01,374] Trial 248 finished with value: 0.4357595533663227 and parameters: {'learning_rate': 0.015169567230915613, 'min_child_weight': 6, 'min_child_samples': 14, 'subsample': 0.6354262649698711, 'colsample_bytree': 0.6030401362525717, 'num_leaves': 30, 'max_bin': 363, 'reg_alpha': 0.08624186390001046, 'reg_lambda': 0.17945014160629286, 'n_estimators': 368}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:01,572] Trial 230 finished with value: 0.4405197452436976 and parameters: {'learning_rate': 0.013436602457056739, 'min_child_weight': 6, 'min_child_samples': 26, 'subsample': 0.6555943897039482, 'colsample_bytree': 0.6447000239804995, 'num_leaves': 96, 'max_bin': 365, 'reg_alpha': 0.0551789078343454, 'reg_lambda': 0.8960977926933023, 'n_estimators': 369}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:02,290] Trial 251 finished with value: 0.4358409059397649 and parameters: {'learning_rate': 0.015296151425248344, 'min_child_weight': 6, 'min_child_samples': 15, 'subsample': 0.6326357210220435, 'colsample_bytree': 0.6000110686795734, 'num_leaves': 31, 'max_bin': 364, 'reg_alpha': 0.11238695189273257, 'reg_lambda': 0.20313340385202855, 'n_estimators': 349}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:02,607] Trial 252 finished with value: 0.4356735137790047 and parameters: {'learning_rate': 0.013886605127281185, 'min_child_weight': 6, 'min_child_samples': 16, 'subsample': 0.6405936497912866, 'colsample_bytree': 0.5943023573664818, 'num_leaves': 29, 'max_bin': 360, 'reg_alpha': 0.07759637604704253, 'reg_lambda': 0.19120347900650864, 'n_estimators': 349}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:02,685] Trial 250 finished with value: 0.44037859908846794 and parameters: {'learning_rate': 0.03079577758574644, 'min_child_weight': 6, 'min_child_samples': 15, 'subsample': 0.6430832873093215, 'colsample_bytree': 0.5934417071080768, 'num_leaves': 31, 'max_bin': 357, 'reg_alpha': 0.09266526868229397, 'reg_lambda': 0.10939755920506912, 'n_estimators': 376}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:03,303] Trial 253 finished with value: 0.4353866223800174 and parameters: {'learning_rate': 0.013340734390302613, 'min_child_weight': 6, 'min_child_samples': 15, 'subsample': 0.6367462052969797, 'colsample_bytree': 0.5994384763724854, 'num_leaves': 31, 'max_bin': 358, 'reg_alpha': 0.1055865630052377, 'reg_lambda': 0.19974240419060413, 'n_estimators': 342}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:03,359] Trial 263 finished with value: 0.4554948640603026 and parameters: {'learning_rate': 0.010206606740820098, 'min_child_weight': 6, 'min_child_samples': 26, 'subsample': 0.6068820347966797, 'colsample_bytree': 0.7723860878713298, 'num_leaves': 20, 'max_bin': 358, 'reg_alpha': 0.025200693821051084, 'reg_lambda': 0.14710839416063287, 'n_estimators': 101}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:03,781] Trial 254 finished with value: 0.43558985429428687 and parameters: {'learning_rate': 0.013383192402847958, 'min_child_weight': 6, 'min_child_samples': 16, 'subsample': 0.6428783539291396, 'colsample_bytree': 0.6048563309928316, 'num_leaves': 30, 'max_bin': 357, 'reg_alpha': 0.16979413449906247, 'reg_lambda': 0.10561453125477682, 'n_estimators': 377}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:04,103] Trial 255 finished with value: 0.43554530421786064 and parameters: {'learning_rate': 0.013154032130550487, 'min_child_weight': 6, 'min_child_samples': 16, 'subsample': 0.6453526155246132, 'colsample_bytree': 0.5990894507132344, 'num_leaves': 30, 'max_bin': 360, 'reg_alpha': 0.03306753415262901, 'reg_lambda': 0.16746646858561853, 'n_estimators': 378}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:05,349] Trial 262 finished with value: 0.4385171266064124 and parameters: {'learning_rate': 0.0336060435355715, 'min_child_weight': 6, 'min_child_samples': 17, 'subsample': 0.6445195107802585, 'colsample_bytree': 0.5896906650890114, 'num_leaves': 18, 'max_bin': 354, 'reg_alpha': 0.08146708922670247, 'reg_lambda': 0.1819516045451286, 'n_estimators': 387}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:05,404] Trial 210 finished with value: 0.44546427898738034 and parameters: {'learning_rate': 0.013433077553022458, 'min_child_weight': 6, 'min_child_samples': 8, 'subsample': 0.7333693524245025, 'colsample_bytree': 0.6391599091011961, 'num_leaves': 209, 'max_bin': 241, 'reg_alpha': 0.6541901569610542, 'reg_lambda': 0.7972007326655358, 'n_estimators': 392}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:05,463] Trial 261 finished with value: 0.43500578871196227 and parameters: {'learning_rate': 0.010030588880820993, 'min_child_weight': 6, 'min_child_samples': 16, 'subsample': 0.6431897967677663, 'colsample_bytree': 0.6229027896048456, 'num_leaves': 19, 'max_bin': 383, 'reg_alpha': 0.02351062015753915, 'reg_lambda': 0.17162554886916004, 'n_estimators': 387}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:05,689] Trial 258 finished with value: 0.43598652886928924 and parameters: {'learning_rate': 0.013272373989522003, 'min_child_weight': 6, 'min_child_samples': 45, 'subsample': 0.642401994513037, 'colsample_bytree': 0.5906547562717116, 'num_leaves': 30, 'max_bin': 377, 'reg_alpha': 0.21698598397170976, 'reg_lambda': 0.17443827097302275, 'n_estimators': 387}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:05,837] Trial 259 finished with value: 0.4394584906606401 and parameters: {'learning_rate': 0.03065387767817308, 'min_child_weight': 6, 'min_child_samples': 26, 'subsample': 0.6454411548242623, 'colsample_bytree': 0.592972696816904, 'num_leaves': 32, 'max_bin': 355, 'reg_alpha': 0.037063015206800776, 'reg_lambda': 0.20156966331557188, 'n_estimators': 348}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:06,101] Trial 219 finished with value: 0.4441440087184336 and parameters: {'learning_rate': 0.01362974154053922, 'min_child_weight': 6, 'min_child_samples': 24, 'subsample': 0.5701455260812381, 'colsample_bytree': 0.641726588087088, 'num_leaves': 244, 'max_bin': 225, 'reg_alpha': 0.686955476972518, 'reg_lambda': 0.8577131228647207, 'n_estimators': 367}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:06,164] Trial 257 finished with value: 0.44042193279148606 and parameters: {'learning_rate': 0.030493674927991793, 'min_child_weight': 6, 'min_child_samples': 16, 'subsample': 0.6101342157273174, 'colsample_bytree': 0.5945750194197646, 'num_leaves': 30, 'max_bin': 380, 'reg_alpha': 0.08435991192564489, 'reg_lambda': 0.18825752985669586, 'n_estimators': 388}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:06,681] Trial 200 finished with value: 0.46025516860472676 and parameters: {'learning_rate': 0.020064550575786183, 'min_child_weight': 6, 'min_child_samples': 28, 'subsample': 0.5375225602892298, 'colsample_bytree': 0.6355124500025837, 'num_leaves': 184, 'max_bin': 282, 'reg_alpha': 0.024330526862874846, 'reg_lambda': 0.7984738951880836, 'n_estimators': 416}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:06,799] Trial 256 finished with value: 0.4354384250373943 and parameters: {'learning_rate': 0.013210899020521295, 'min_child_weight': 6, 'min_child_samples': 15, 'subsample': 0.6451563168819057, 'colsample_bytree': 0.77806267201289, 'num_leaves': 31, 'max_bin': 358, 'reg_alpha': 0.03689486713773161, 'reg_lambda': 0.18944588257234818, 'n_estimators': 386}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,053] Trial 260 finished with value: 0.4353740965646167 and parameters: {'learning_rate': 0.011424821983813673, 'min_child_weight': 6, 'min_child_samples': 26, 'subsample': 0.6441762593046291, 'colsample_bytree': 0.5885025827023574, 'num_leaves': 31, 'max_bin': 383, 'reg_alpha': 0.16815607264330795, 'reg_lambda': 0.20277164144363186, 'n_estimators': 349}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,111] Trial 264 finished with value: 0.4350281897747499 and parameters: {'learning_rate': 0.010063673615351413, 'min_child_weight': 6, 'min_child_samples': 12, 'subsample': 0.6127365801430232, 'colsample_bytree': 0.6243553274707734, 'num_leaves': 18, 'max_bin': 371, 'reg_alpha': 0.2228836115122893, 'reg_lambda': 0.1578303401511101, 'n_estimators': 386}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,195] Trial 265 finished with value: 0.43514620201141435 and parameters: {'learning_rate': 0.010060708123122162, 'min_child_weight': 6, 'min_child_samples': 12, 'subsample': 0.6459336544404193, 'colsample_bytree': 0.6241326488150593, 'num_leaves': 18, 'max_bin': 375, 'reg_alpha': 0.16789980218385836, 'reg_lambda': 0.17376463210635534, 'n_estimators': 388}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,552] Trial 221 finished with value: 0.4440301360418525 and parameters: {'learning_rate': 0.013105187934318911, 'min_child_weight': 6, 'min_child_samples': 24, 'subsample': 0.7307240962655939, 'colsample_bytree': 0.6411709273544905, 'num_leaves': 236, 'max_bin': 244, 'reg_alpha': 0.68921096644881, 'reg_lambda': 0.8613034683560126, 'n_estimators': 372}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,755] Trial 270 finished with value: 0.43742916016636113 and parameters: {'learning_rate': 0.01144673188709453, 'min_child_weight': 6, 'min_child_samples': 26, 'subsample': 0.7073782921171338, 'colsample_bytree': 0.6236019732270361, 'num_leaves': 8, 'max_bin': 383, 'reg_alpha': 0.2058015557075273, 'reg_lambda': 0.24066417237086518, 'n_estimators': 388}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,795] Trial 271 finished with value: 0.43729259533973897 and parameters: {'learning_rate': 0.011436416166210335, 'min_child_weight': 6, 'min_child_samples': 12, 'subsample': 0.6887062867712215, 'colsample_bytree': 0.6284265838811214, 'num_leaves': 8, 'max_bin': 373, 'reg_alpha': 0.6758070521151652, 'reg_lambda': 0.2269838098044821, 'n_estimators': 385}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,865] Trial 272 finished with value: 0.43734965294676764 and parameters: {'learning_rate': 0.011369069472714339, 'min_child_weight': 6, 'min_child_samples': 44, 'subsample': 0.6682181558481738, 'colsample_bytree': 0.6236807125087582, 'num_leaves': 8, 'max_bin': 383, 'reg_alpha': 0.21978160389743506, 'reg_lambda': 0.14289028685896243, 'n_estimators': 385}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,956] Trial 266 finished with value: 0.43497894064363873 and parameters: {'learning_rate': 0.010108017260692895, 'min_child_weight': 6, 'min_child_samples': 12, 'subsample': 0.6678615695003844, 'colsample_bytree': 0.6250160624823121, 'num_leaves': 19, 'max_bin': 375, 'reg_alpha': 0.02083810009768306, 'reg_lambda': 0.21203232814265033, 'n_estimators': 387}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:07,997] Trial 267 finished with value: 0.43476869633836734 and parameters: {'learning_rate': 0.011547767511829803, 'min_child_weight': 6, 'min_child_samples': 26, 'subsample': 0.6692230432170746, 'colsample_bytree': 0.6230941688623599, 'num_leaves': 19, 'max_bin': 376, 'reg_alpha': 0.16444662612875063, 'reg_lambda': 0.14415951401059554, 'n_estimators': 385}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:08,121] Trial 273 finished with value: 0.4386960932670826 and parameters: {'learning_rate': 0.04665273850934635, 'min_child_weight': 6, 'min_child_samples': 13, 'subsample': 0.6688628795342211, 'colsample_bytree': 0.6250315182503827, 'num_leaves': 8, 'max_bin': 372, 'reg_alpha': 0.17075258928476122, 'reg_lambda': 0.2253703596848795, 'n_estimators': 387}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:08,428] Trial 268 finished with value: 0.4349797866312117 and parameters: {'learning_rate': 0.011686700855634908, 'min_child_weight': 6, 'min_child_samples': 13, 'subsample': 0.689354736643854, 'colsample_bytree': 0.6244944080088579, 'num_leaves': 18, 'max_bin': 377, 'reg_alpha': 0.1623827272392574, 'reg_lambda': 0.1421304918719164, 'n_estimators': 387}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:08,557] Trial 269 finished with value: 0.4349875699385127 and parameters: {'learning_rate': 0.011518225590433322, 'min_child_weight': 6, 'min_child_samples': 13, 'subsample': 0.7085098961535297, 'colsample_bytree': 0.626049543400027, 'num_leaves': 18, 'max_bin': 373, 'reg_alpha': 0.23591875410865487, 'reg_lambda': 0.8530707958773726, 'n_estimators': 388}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:08,949] Trial 224 finished with value: 0.44424807981732345 and parameters: {'learning_rate': 0.013492743140675823, 'min_child_weight': 6, 'min_child_samples': 24, 'subsample': 0.695410337769513, 'colsample_bytree': 0.6138673377760738, 'num_leaves': 202, 'max_bin': 225, 'reg_alpha': 0.6665410959926058, 'reg_lambda': 0.8740931368685242, 'n_estimators': 370}. Best is trial 175 with value: 0.4347499065662622.
# [I 2021-09-30 10:22:08,968] Trial 277 finished with value: 0.4415037787219145 and parameters: {'learning_rate': 0.011452901145775097, 'min_child_weight': 6, 'min_child_samples': 19, 'subsample': 0.666134247464134, 'colsample_bytree': 0.6207828257248843, 'num_leaves': 18, 'max_bin': 371, 'reg_alpha': 0.015321320609442928, 'reg_lambda': 0.13729947877548387, 'n_estimators': 171}. Best is trial 175 with value: 0.4347499065662622.

# %%
best_params = study.best_params
best_params

# %%
# RandomForest, XGBClassifier, LGBMClassifier(BASELINE), LGBMClassifier(최적화) 모델 성능 비교
model = LGBMClassifier(**study.best_params, n_jobs=-1)
model.fit(trn[features], trn.target)
tst_preds = model.predict(tst[features])
pred_proba_list.append(model.predict_proba(tst[features]))

model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)']
result = make_result_df(model_names, pred_proba_list)
result

# %%
# RandomForest, XGBClassifier, LGBMClassifier(BASELINE), LGBMClassifier(최적화) 모델의 roc_curve를 그려보겠습니다.
# roc_curve 함수는 False Positive Rate, True Positive Rate, Threshold를 반환합니다.
fig, ax = plt.subplots(figsize=(8, 6))
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)']
random_x = np.linspace(0, 1, 15)
random_y = np.linspace(0, 1, 15)
ax.plot(random_x, random_y, label='Random', color='black', ls=':', lw=1.5)
for pred_proba, model_name in zip(pred_proba_list, model_names):    
    fprs, tprs, _ = roc_curve(tst.target, pred_proba[:, 1])     
    ax.plot(fprs, tprs, label=model_name)    
ax.legend(loc='lower right') # 범례 생성
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1.1)
ax.set_title('ROC CURVE', fontsize=15, fontweight='bold')
plt.show()
# ROC-CURVE로 모델의 성능을 비교해봅니다.

# %%
# NN 모델
def create_model(trn, numeric, categorical):
    cat_inputs, cat_outputs = [], []
    num_input = layers.Input(shape=(len(numeric), ))
    for col in categorical:
        nunique = trn[col].nunique()    
        embed_dim = int(min(np.ceil(nunique/2), 50))
        cat_input = layers.Input(shape=(1, ))    
        cat_output = layers.Embedding(nunique+1, embed_dim)(cat_input)
        cat_output = layers.SpatialDropout1D(0.3)(cat_output)
        cat_output = layers.Flatten()(cat_output)
        cat_inputs.append(cat_input)
        cat_outputs.append(cat_output)
    x = layers.Concatenate()(cat_outputs + [num_input])    
    x = layers.BatchNormalization()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.BatchNormalization()(x)
    output = layers.Dense(2, activation='softmax')(x)

    model = tf.keras.models.Model([num_input, cat_inputs], output)
    model.compile(
        optimizer=tf.optimizers.Adam(learning_rate=0.01), loss='categorical_crossentropy',
        metrics=['acc'])
    return model

# %%
trn, tst = load_data()
trn, tst = labelencoder(trn, tst)
features = trn.drop('target', axis=1).columns

# numeric feature는 정규화 합니다.
numeric = ['city_development_index', 'training_hours', 'num_missing']
categorical = list(col for col in trn.columns if col not in numeric and col!='target')
for col in numeric:
    ss = StandardScaler()
    trn[col] = ss.fit_transform(trn[col].values.reshape(-1, 1))
    tst[col] = ss.transform(tst[col].values.reshape(-1, 1))
print(trn.shape, tst.shape)

# %%
model = create_model(trn, numeric, categorical)
# 위의 모델은 numric, categorical feature 순으로 데이터를 넣어주어야 한다.
y_trn = to_categorical(trn.target.values)
y_tst = to_categorical(tst.target.values)
ec = EarlyStopping(monitor='val_loss', verbose=0, mode='min', patience=5)
tf_board = TensorBoard(log_dir='logs', histogram_freq=1, embeddings_freq=1)
history = model.fit(
    [trn[numeric].values, list(trn[col].values for col in categorical)], y_trn,
    epochs=100, verbose=1, batch_size=64, validation_split=0.2, shuffle=False,
#     callbacks=[ec, tf_board]
    callbacks=[ec]
)

# %%
if len(pred_proba_list)>4:
    pred_proba_list = pred_proba_list[:4]

# NN모델의 예측값을 추가하고
pred_proba_list.append(model.predict([tst[numeric].values, list(tst[col].values for col in categorical)]))
# 총 5가지 모델을 비교
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
result = make_result_df(model_names, pred_proba_list)
result

# %%
if len(pred_proba_list)>4:
    pred_proba_list = pred_proba_list[:4]

# NN모델의 예측값을 추가하고
pred_proba_list.append(model.predict([tst[numeric].values, list(tst[col].values for col in categorical)]))
# 총 5가지 모델을 비교
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
result = make_result_df(model_names, pred_proba_list)
result

# %%
# NN모델의 예측값을 추가하고
#pred_proba_list.append(model.predict([tst[numeric].values, list(tst[col].values for col in categorical)]))
# 총 5가지 모델을 비교
#model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
#result = make_result_df(model_names, pred_proba_list)
#result

# %%
# 5개 모델을 ROC_CURVE로 비교합니다.
fig, ax = plt.subplots(figsize=(20, 9))
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
random_x = np.linspace(0, 1, 15)
random_y = np.linspace(0, 1, 15)
ax.plot(random_x, random_y, label='Random', color='black', ls=':', lw=1.5)
for pred_proba, model_name in zip(pred_proba_list, model_names):    
    fprs, tprs, _ = roc_curve(tst.target, pred_proba[:, 1])     
    ax.plot(fprs, tprs, label=model_name)    
ax.legend(loc='lower right') # 범례 생성
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1.1)
ax.set_title('ROC CURVE', fontsize=15, fontweight='bold')
plt.show()
# ROC-CURVE로 모델의 성능을 비교해봅니다.

# %%
# !tensorboard --logdir=logs
