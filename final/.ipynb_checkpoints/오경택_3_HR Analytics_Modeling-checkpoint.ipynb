# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 13019561105414535475
# ]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import accuracy_score, log_loss, confusion_matrix, roc_curve, roc_auc_score
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from imblearn.over_sampling import SMOTE
import warnings, graphviz, optuna, pydot
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.callbacks import EarlyStopping, TensorBoard
from tensorflow.keras.utils import to_categorical
warnings.filterwarnings('ignore')
sns.set(style='white')
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['axes.titlesize'] = 16
plt.rcParams['axes.titleweight'] = 'bold'
plt.rcParams['axes.labelsize'] = 13
plt.rcParams['axes.labelweight'] = 'bold'
np.random.seed(0)
tf.random.set_seed(0)

# %%
trn = pd.read_csv('aug_train.csv')
tst = pd.read_csv('aug_test.csv')
tst_answer = np.load('jobchange_test_target_values.npy')
tst['target'] = tst_answer
trn.drop('enrollee_id', axis=1, inplace=True)
tst.drop('enrollee_id', axis=1, inplace=True)
trn['city'] = trn['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))
tst['city'] = tst['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))

# 모든 Null 값을 Missing으로 변경합니다.
for col in tst.columns:
    trn[col].fillna('Missing', inplace=True)
    tst[col].fillna('Missing', inplace=True)
    
# Missing 값의 갯수 Feature 생성
trn['num_missing'] = (trn=='Missing').sum(axis=1)
tst['num_missing'] = (tst=='Missing').sum(axis=1)
    
print(f"train data size: {trn.shape}, test data size: {tst.shape}")
trn.head(2)
# Out:
# train data size: (19158, 14), test data size: (2129, 14)
#        city  city_development_index gender      relevent_experience  \
# 0  city_103                   0.920   Male  Has relevent experience
# 1  city_040                   0.776   Male   No relevent experience
#
#   enrolled_university education_level major_discipline experience  \
# 0       no_enrollment        Graduate             STEM        >20
# 1       no_enrollment        Graduate             STEM         15
#
#   company_size company_type last_new_job  training_hours  target  num_missing
# 0      Missing      Missing            1              36     1.0            2
# 1        50-99      Pvt Ltd           >4              47     0.0            0

# %%
trn_info = pd.concat(
    [
        trn.dtypes,        
        trn.isnull().sum(),
        trn.isnull().sum() / trn.shape[0],
        trn.nunique(),
        tst.nunique()
    ], axis=1
)
trn_info.columns=['data_types', 'Num_of_Null', 'Null_ratio', 'Num_of_unique_values(train)', 'Num_of_unique_values(test)']
trn_info.iloc[:-1, :].style.background_gradient()
# Null값이 상당히 많습니다.
# Out:
# <style type="text/css">
# #T_c0abf_row0_col1, #T_c0abf_row0_col2, #T_c0abf_row1_col1, #T_c0abf_row1_col2, #T_c0abf_row2_col1, #T_c0abf_row2_col2, #T_c0abf_row3_col1, #T_c0abf_row3_col2, #T_c0abf_row3_col3, #T_c0abf_row3_col4, #T_c0abf_row4_col1, #T_c0abf_row4_col2, #T_c0abf_row5_col1, #T_c0abf_row5_col2, #T_c0abf_row6_col1, #T_c0abf_row6_col2, #T_c0abf_row7_col1, #T_c0abf_row7_col2, #T_c0abf_row8_col1, #T_c0abf_row8_col2, #T_c0abf_row9_col1, #T_c0abf_row9_col2, #T_c0abf_row10_col1, #T_c0abf_row10_col2, #T_c0abf_row11_col1, #T_c0abf_row11_col2, #T_c0abf_row12_col1, #T_c0abf_row12_col2, #T_c0abf_row12_col3, #T_c0abf_row12_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_c0abf_row0_col3 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_c0abf_row0_col4 {
#   background-color: #7dacd1;
#   color: #f1f1f1;
# }
# #T_c0abf_row1_col3 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_c0abf_row1_col4 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_c0abf_row2_col3, #T_c0abf_row2_col4, #T_c0abf_row4_col3, #T_c0abf_row4_col4 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_c0abf_row5_col3, #T_c0abf_row5_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_c0abf_row6_col3, #T_c0abf_row6_col4, #T_c0abf_row9_col3, #T_c0abf_row9_col4, #T_c0abf_row10_col3, #T_c0abf_row10_col4 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_c0abf_row7_col3 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_c0abf_row7_col4 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_c0abf_row8_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_c0abf_row8_col4 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_c0abf_row11_col3, #T_c0abf_row11_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c0abf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >data_types</th>
#       <th class="col_heading level0 col1" >Num_of_Null</th>
#       <th class="col_heading level0 col2" >Null_ratio</th>
#       <th class="col_heading level0 col3" >Num_of_unique_values(train)</th>
#       <th class="col_heading level0 col4" >Num_of_unique_values(test)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c0abf_level0_row0" class="row_heading level0 row0" >city</th>
#       <td id="T_c0abf_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_c0abf_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c0abf_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_c0abf_row0_col3" class="data row0 col3" >123</td>
#       <td id="T_c0abf_row0_col4" class="data row0 col4" >108</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row1" class="row_heading level0 row1" >city_development_index</th>
#       <td id="T_c0abf_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_c0abf_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_c0abf_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_c0abf_row1_col3" class="data row1 col3" >93</td>
#       <td id="T_c0abf_row1_col4" class="data row1 col4" >81</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row2" class="row_heading level0 row2" >gender</th>
#       <td id="T_c0abf_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_c0abf_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_c0abf_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_c0abf_row2_col3" class="data row2 col3" >4</td>
#       <td id="T_c0abf_row2_col4" class="data row2 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row3" class="row_heading level0 row3" >relevent_experience</th>
#       <td id="T_c0abf_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_c0abf_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_c0abf_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_c0abf_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_c0abf_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row4" class="row_heading level0 row4" >enrolled_university</th>
#       <td id="T_c0abf_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_c0abf_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_c0abf_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_c0abf_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_c0abf_row4_col4" class="data row4 col4" >4</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row5" class="row_heading level0 row5" >education_level</th>
#       <td id="T_c0abf_row5_col0" class="data row5 col0" >object</td>
#       <td id="T_c0abf_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_c0abf_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_c0abf_row5_col3" class="data row5 col3" >6</td>
#       <td id="T_c0abf_row5_col4" class="data row5 col4" >6</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row6" class="row_heading level0 row6" >major_discipline</th>
#       <td id="T_c0abf_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_c0abf_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_c0abf_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_c0abf_row6_col3" class="data row6 col3" >7</td>
#       <td id="T_c0abf_row6_col4" class="data row6 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row7" class="row_heading level0 row7" >experience</th>
#       <td id="T_c0abf_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_c0abf_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_c0abf_row7_col2" class="data row7 col2" >0.000000</td>
#       <td id="T_c0abf_row7_col3" class="data row7 col3" >23</td>
#       <td id="T_c0abf_row7_col4" class="data row7 col4" >23</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row8" class="row_heading level0 row8" >company_size</th>
#       <td id="T_c0abf_row8_col0" class="data row8 col0" >object</td>
#       <td id="T_c0abf_row8_col1" class="data row8 col1" >0</td>
#       <td id="T_c0abf_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_c0abf_row8_col3" class="data row8 col3" >9</td>
#       <td id="T_c0abf_row8_col4" class="data row8 col4" >9</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row9" class="row_heading level0 row9" >company_type</th>
#       <td id="T_c0abf_row9_col0" class="data row9 col0" >object</td>
#       <td id="T_c0abf_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_c0abf_row9_col2" class="data row9 col2" >0.000000</td>
#       <td id="T_c0abf_row9_col3" class="data row9 col3" >7</td>
#       <td id="T_c0abf_row9_col4" class="data row9 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row10" class="row_heading level0 row10" >last_new_job</th>
#       <td id="T_c0abf_row10_col0" class="data row10 col0" >object</td>
#       <td id="T_c0abf_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_c0abf_row10_col2" class="data row10 col2" >0.000000</td>
#       <td id="T_c0abf_row10_col3" class="data row10 col3" >7</td>
#       <td id="T_c0abf_row10_col4" class="data row10 col4" >7</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row11" class="row_heading level0 row11" >training_hours</th>
#       <td id="T_c0abf_row11_col0" class="data row11 col0" >int64</td>
#       <td id="T_c0abf_row11_col1" class="data row11 col1" >0</td>
#       <td id="T_c0abf_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_c0abf_row11_col3" class="data row11 col3" >241</td>
#       <td id="T_c0abf_row11_col4" class="data row11 col4" >223</td>
#     </tr>
#     <tr>
#       <th id="T_c0abf_level0_row12" class="row_heading level0 row12" >target</th>
#       <td id="T_c0abf_row12_col0" class="data row12 col0" >float64</td>
#       <td id="T_c0abf_row12_col1" class="data row12 col1" >0</td>
#       <td id="T_c0abf_row12_col2" class="data row12 col2" >0.000000</td>
#       <td id="T_c0abf_row12_col3" class="data row12 col3" >2</td>
#       <td id="T_c0abf_row12_col4" class="data row12 col4" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
for col in trn.select_dtypes(include='object').columns:
    print(f"{col} feature의 unique value train/test 동일 여부: {sorted(trn[col].unique()) == sorted(tst[col].unique())}")
print("="*100)
# city를 빼고는 train과 test 셋의 unique values가 동일합니다.
# 문제는 test에는 있는 city가 train에 있을 경우 입니다. 혹시 모르니 확인해봅니다.
for city in tst['city'].unique():
    if city not in trn['city'].unique():
        print('warnings!') 
# 다행히 warnings가 출력되지 않았습니다. 그럼 train 데이터를 기준으로 모두 labelencoding 하겠습니다.
# Out:
# city feature의 unique value train/test 동일 여부: False
# gender feature의 unique value train/test 동일 여부: True
# relevent_experience feature의 unique value train/test 동일 여부: True
# enrolled_university feature의 unique value train/test 동일 여부: True
# education_level feature의 unique value train/test 동일 여부: True
# major_discipline feature의 unique value train/test 동일 여부: True
# experience feature의 unique value train/test 동일 여부: True
# company_size feature의 unique value train/test 동일 여부: True
# company_type feature의 unique value train/test 동일 여부: True
# last_new_job feature의 unique value train/test 동일 여부: True
# ====================================================================================================

# %%
# 데이터 불러오기  /  labelencoding 함수 정의
def load_data():
    trn = pd.read_csv('aug_train.csv')
    tst = pd.read_csv('aug_test.csv')
    tst_answer = np.load('jobchange_test_target_values.npy')
    tst['target'] = tst_answer
    trn.drop('enrollee_id', axis=1, inplace=True)
    tst.drop('enrollee_id', axis=1, inplace=True)
    trn['city'] = trn['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))
    tst['city'] = tst['city'].map(lambda x: 'city_'+str(int(x[5:])).zfill(3))

    # 모든 Null 값을 Missing으로 변경합니다.
    for col in tst.columns:
        trn[col].fillna('Missing', inplace=True)
        tst[col].fillna('Missing', inplace=True)

    # Missing 값의 갯수 Feature 생성
    trn['num_missing'] = (trn=='Missing').sum(axis=1)
    tst['num_missing'] = (tst=='Missing').sum(axis=1)
    return trn, tst

def labelencoder(train, test):
    # normianl feature는 labelencoder로 처리
    norminal = ['city', 'gender', 'relevent_experience', 'major_discipline', 'company_type']
    for col in norminal:
        le = LabelEncoder()
        train[col] = le.fit_transform(train[col])
        test[col] = le.transform(test[col])

    # ordinal feature는 자체적으로 생성한 dictionary로 처리합니다
    ordinal = {
        'enrolled_university':{'Full time course':3, 'Part time course':2, 'no_enrollment':1, 'Missing':0},
        'education_level':{'Phd':5, 'Masters':4, 'Graduate':3, 'High School':2, 'Primary School':1, 'Missing':0},
        'experience':{
            '>20':22, '20':21, '19':20, '18':19, '17':18, '16':17, '15':16, '14':15, '13':14, '12':13, '11':12, '10':11,
            '9':10, '8':9, '7':8, '6':7, '5':6, '4':5, '3':4, '2':3, '1':2 , '<1':1, 'Missing':0
        },
        'company_size':{'10000+':8, '5000-9999':7, '1000-4999':6, '500-999':5, '100-500':4, '50-99':3, '10/49':2, '<10':1, 'Missing':0},
        'last_new_job':{'>4':6, '4':5, '3':4, '2':3, '1':2, 'never':1, 'Missing':0}
    }
    for col in ordinal:
        train[col] = train[col].map(ordinal[col])
        test[col] = test[col].map(ordinal[col])
    return train, test

# %%
trn, tst = load_data()
trn, tst = labelencoder(trn, tst)
features = trn.drop('target', axis=1).columns
print(trn.shape, tst.shape)
trn.head(2)
# Out:
# (19158, 14) (2129, 14)
#    city  city_development_index  gender  relevent_experience  \
# 0    73                   0.920       1                    0
# 1    27                   0.776       1                    1
#
#    enrolled_university  education_level  major_discipline  experience  \
# 0                    1                3                 6          22
# 1                    1                3                 6          16
#
#    company_size  company_type  last_new_job  training_hours  target  \
# 0             0             2             2              36     1.0
# 1             3             6             6              47     0.0
#
#    num_missing
# 0            2
# 1            0

# %%
dataset_info = pd.concat(
    [
        trn.dtypes, trn.isnull().sum(), tst.dtypes, tst.isnull().sum()
    ], axis=1
)
dataset_info.columns = ['train_dtypes', 'train_Num_of_Nulls', 'test_dtypes', 'test_Num_of_Nulls']
dataset_info # 모든 feature가 numeric으로 변경되었고 Null도 없습니다. 이제 baseline model을 생성하겠습니다.
# Out:
#                        train_dtypes  train_Num_of_Nulls test_dtypes  \
# city                          int32                   0       int32
# city_development_index      float64                   0     float64
# gender                        int32                   0       int32
# relevent_experience           int32                   0       int32
# enrolled_university           int64                   0       int64
# education_level               int64                   0       int64
# major_discipline              int32                   0       int32
# experience                    int64                   0       int64
# company_size                  int64                   0       int64
# company_type                  int32                   0       int32
# last_new_job                  int64                   0       int64
# training_hours                int64                   0       int64
# target                      float64                   0     float64
# num_missing                   int64                   0       int64
#
#                         test_Num_of_Nulls
# city                                    0
# city_development_index                  0
# gender                                  0
# relevent_experience                     0
# enrolled_university                     0
# education_level                         0
# major_discipline                        0
# experience                              0
# company_size                            0
# company_type                            0
# last_new_job                            0
# training_hours                          0
# target                                  0
# num_missing                             0

# %%
# DecisionTree 시각화 부터 시작합니다.
features = trn.drop('target', axis=1).columns
# 먼저 random 모델의 성능을 확인합니다. 단순하게 모든 target을 0으로 예측하면 정확도는
print(f"모든 데이터를 0으로 예측하면 train dataset의 정확도는: {format((trn['target'].value_counts() / trn.shape[0]).values[0], '.1%')}")
print(f"모든 데이터를 0으로 예측하면 test dataset의 정확도는: {format((tst['target'].value_counts() / tst.shape[0]).values[0], '.1%')}")
# 최소한 아래 정확도는 넘겨야 합니다.
# Out:
# 모든 데이터를 0으로 예측하면 train dataset의 정확도는: 75.1%
# 모든 데이터를 0으로 예측하면 test dataset의 정확도는: 72.9%

# %%
# 먼저 트리 시각화를 위해 decisiontree 모델을 사용합니다.
model = DecisionTreeClassifier(max_depth=5)
model.fit(trn[features], trn['target'])
trn_pred = model.predict(trn[features])
tst_pred = model.predict(tst[features])
tst_pred_proba = model.predict_proba(tst[features])
print(f"accuracy_score in train dataset: {accuracy_score(trn.target, trn_pred):.1%}")
print(f"accuracy_score in test dataset: {accuracy_score(tst.target, tst_pred):.1%}")
print(f"log_loss in test dataset: {log_loss(tst.target, tst_pred_proba):.4f}")
print(f"roc_auc_score in test dataset: {roc_auc_score(tst.target, tst_pred):.4f}")
fig, axes = plt.subplots(figsize=(15, 6), ncols=2)
sns.heatmap(
    confusion_matrix(trn.target, trn_pred), ax=axes[0], annot=True, fmt=",", cbar=False, cmap='Blues',
    annot_kws={'fontweight':'bold'}
)
sns.heatmap(
    confusion_matrix(tst.target, tst_pred), ax=axes[1], annot=True, fmt=",", cbar=False, cmap='Blues',
    annot_kws={'fontweight':'bold'}
)
axes[0].set_title('Train Confusion Matrix')
axes[0].set_xlabel('Predicted Label')
axes[0].set_ylabel('True Label')
axes[1].set_title('Test Confusion Matrix')
axes[1].set_xlabel('Predicted Label')
axes[1].set_ylabel('True Label')
plt.show()
# 아주 약간 높습니다. 트리 시각화를 위해 최적의 max_depth를 찾아보겠습니다.
# Out:
# accuracy_score in train dataset: 79.2%
# accuracy_score in test dataset: 78.8%
# log_loss in test dataset: 0.4963
# roc_auc_score in test dataset: 0.7248

# %%
# max_depth에 따른 정확도를 시각화 합니다.
trn_acc_list, tst_acc_list = [], []
for max_depth in range(3, 20):
    model = DecisionTreeClassifier(max_depth=max_depth)
    model.fit(trn[features], trn['target'])
    trn_acc = accuracy_score(model.predict(trn[features]), trn.target)
    tst_acc = accuracy_score(model.predict(tst[features]), tst.target)    
    trn_acc_list.append(trn_acc)
    tst_acc_list.append(tst_acc)

fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(range(3, 20), trn_acc_list, label='train accuracy', color='grey')
ax.plot(range(3, 20), tst_acc_list, label='test accuracy', color="#d1495b")
ax.set_xlabel('Max Depth')
ax.set_ylabel('accuracy')
ax.set_yticklabels(list(format(y, ".1%") for y in ax.get_yticks()))
ax.legend(loc='upper center', ncol=2)
ax.set_title('Model Accuracy by Max Depth')
plt.show()
# max_depth 6부터 과적합입니다. 이제 max_depth 6의 트리모델을 시각화 합니다.

# %%
# DecisionTree 시각화, Max Depth는 5로 설정합니다.
model = DecisionTreeClassifier(max_depth=5)
model.fit(trn[features], trn['target'])

export_graphviz(
    model, out_file="basetree.dot", class_names='target', feature_names=features,
    filled=True, impurity=True
) #export_graphviz로 dot 파일을 생성한 후 

(graph,) = pydot.graph_from_dot_file('basetree.dot')
graph.write_png('basetree_maxdepth_5.png') #dot to png

with open("basetree.dot") as f:
    dot_graph = f.read() #위의 dot파일을 읽고
graphviz.Source(dot_graph) #graphviz.Source()로 그립니다.

# %%
def make_result_df(model_names, pred_proba_list):
    data = np.zeros((len(model_names), 3))
    for idx, pred in enumerate(pred_proba_list):
        data[idx, :] = [
            accuracy_score(tst.target, np.argmax(pred, axis=1)),
            log_loss(tst.target, pred), roc_auc_score(tst.target, np.argmax(pred, axis=1))
        ]
    data = pd.DataFrame(index=model_names, data=data, columns=['acc', 'log_loss', 'roc_score'])
    return data

# %%
# tree 시각화를 끝냈으니 이제 본격적으로 모델을 생성해보겠습니다.
# Randomforest, XGBoost, LightGBM의 모델 성능을 비교해봅니다. 
models = [
    RandomForestClassifier(n_jobs=-1, random_state=0, max_depth=5),
    XGBClassifier(n_jobs=-1, max_depth=5),
    LGBMClassifier(n_jobs=-1)
]
pred_proba_list = []
for model in models:
    result = cross_val_score(model, X=trn[features], y=trn.target, cv=5, scoring='neg_log_loss')
    model.fit(trn[features], trn.target)
    tst_preds = model.predict(tst[features])
    pred_proba_list.append(model.predict_proba(tst[features]))

model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)']
result = make_result_df(model_names, pred_proba_list)
result
# Out:
# [23:39:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:39:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:39:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:39:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:39:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [23:39:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.4.0/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
#                            acc  log_loss  roc_score
# RandomForest          0.782997  0.462287   0.676504
# XGBClassifier         0.774542  0.472222   0.694191
# LGBMClassifier(base)  0.783466  0.460133   0.719422

# %%
# 이번에는 LightGBM 모델을 튜닝해보겠습니다.
def lgbm_object(trial:optuna.Trial, trn):
    X_trn, X_vld, y_trn, y_vld = train_test_split(trn[features], trn.target, test_size=0.2, random_state=0)
    params = {
        # 각 항목에 대해서 자세히 설명은 구글을 참고해주시기 바랍니다. feature가 몇개 없으므로 gamma, reg_lambda와 reg_alpha는 사용하지 않겠습니다.
        'learning_rate' : trial.suggest_float('learning_rate', 0.01, 0.1),
        'min_child_weight' : trial.suggest_int('min_child_weight', 1, 7),
        'min_child_samples' : trial.suggest_int('min_child_samples', 5, 100),
        'subsample' : trial.suggest_float('subsample', 0.5, 1),                
        'colsample_bytree' : trial.suggest_float('colsample_bytree', 0.5, 1),
        'num_leaves' : trial.suggest_int('num_leaves', 2, 256),
        'max_bin' : trial.suggest_int('max_bin', 200, 500),
        'reg_alpha' : trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda' : trial.suggest_float('reg_lambda', 0, 1),  
        'n_estimators' : trial.suggest_int('n_estimators', 100, 500),
    }
    model = LGBMClassifier(**params, seed=0, n_jobs=-1)
    model.fit(X_trn, y_trn, verbose=0)
    return log_loss(y_vld, model.predict_proba(X_vld)) # 모델의 최종 결과값을 반환합니다.
# 평가지표가 log_loss이므로 direction은 minimize 입니다.
study = optuna.create_study(direction='minimize', sampler=optuna.samplers.TPESampler(seed=0))
study.optimize(lambda trial : lgbm_object(trial, trn), n_trials=1000, n_jobs=-1)
# Out:
# [I 2021-09-28 23:39:15,300] A new study created in memory with name: no-name-1b14e584-c839-4046-a35b-27dd31ec3450
# [I 2021-09-28 23:39:17,532] Trial 7 finished with value: 0.4502577654300932 and parameters: {'learning_rate': 0.06924392469553763, 'min_child_weight': 6, 'min_child_samples': 43, 'subsample': 0.6321206054362789, 'colsample_bytree': 0.945039268471363, 'num_leaves': 44, 'max_bin': 473, 'reg_alpha': 0.6861643191989635, 'reg_lambda': 0.07135911618806956, 'n_estimators': 218}. Best is trial 7 with value: 0.4502577654300932.
# [I 2021-09-28 23:39:18,656] Trial 5 finished with value: 0.44260133027352355 and parameters: {'learning_rate': 0.043248065523774214, 'min_child_weight': 6, 'min_child_samples': 62, 'subsample': 0.5226319509201343, 'colsample_bytree': 0.52345913740802, 'num_leaves': 77, 'max_bin': 388, 'reg_alpha': 0.688719503892054, 'reg_lambda': 0.23926912038513015, 'n_estimators': 179}. Best is trial 5 with value: 0.44260133027352355.
# [I 2021-09-28 23:39:19,321] Trial 2 finished with value: 0.45578293316110874 and parameters: {'learning_rate': 0.08019756756808798, 'min_child_weight': 6, 'min_child_samples': 50, 'subsample': 0.9836394816704443, 'colsample_bytree': 0.5511983513983292, 'num_leaves': 113, 'max_bin': 325, 'reg_alpha': 0.6698462294662062, 'reg_lambda': 0.5814273838727932, 'n_estimators': 148}. Best is trial 5 with value: 0.44260133027352355.
# [I 2021-09-28 23:39:20,962] Trial 8 finished with value: 0.47258246923673686 and parameters: {'learning_rate': 0.09737458833099553, 'min_child_weight': 4, 'min_child_samples': 41, 'subsample': 0.803190304301411, 'colsample_bytree': 0.8591500317141153, 'num_leaves': 101, 'max_bin': 499, 'reg_alpha': 0.7209847970834526, 'reg_lambda': 0.7284395403663934, 'n_estimators': 159}. Best is trial 5 with value: 0.44260133027352355.
# [I 2021-09-28 23:39:21,286] Trial 4 finished with value: 0.4482464008727701 and parameters: {'learning_rate': 0.02528525998130736, 'min_child_weight': 7, 'min_child_samples': 77, 'subsample': 0.7269699474278353, 'colsample_bytree': 0.8760688513160839, 'num_leaves': 82, 'max_bin': 497, 'reg_alpha': 0.1474959466655139, 'reg_lambda': 0.9171839461960205, 'n_estimators': 339}. Best is trial 5 with value: 0.44260133027352355.
# [I 2021-09-28 23:39
. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:36,682] Trial 27 finished with value: 0.45434478676244505 and parameters: {'learning_rate': 0.010776088740190315, 'min_child_weight': 5, 'min_child_samples': 24, 'subsample': 0.5009625078352106, 'colsample_bytree': 0.7251934252795127, 'num_leaves': 66, 'max_bin': 439, 'reg_alpha': 0.26505864803698287, 'reg_lambda': 0.5733772940697353, 'n_estimators': 101}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:37,451] Trial 28 finished with value: 0.456762163926682 and parameters: {'learning_rate': 0.01005909143316349, 'min_child_weight': 5, 'min_child_samples': 100, 'subsample': 0.6807811566046776, 'colsample_bytree': 0.7236561483231855, 'num_leaves': 59, 'max_bin': 439, 'reg_alpha': 0.27518877111321594, 'reg_lambda': 0.26613202357782223, 'n_estimators': 107}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:38,819] Trial 10 finished with value: 0.47718621038674075 and parameters: {'learning_rate': 0.03308675815905195, 'min_child_weight': 1, 'min_child_samples': 41, 'subsample': 0.6139022867650356, 'colsample_bytree': 0.5362097201938367, 'num_leaves': 230, 'max_bin': 224, 'reg_alpha': 0.03486209814544183, 'reg_lambda': 0.24956067245106894, 'n_estimators': 347}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:38,929] Trial 30 finished with value: 0.4378456873858048 and parameters: {'learning_rate': 0.035453284901813945, 'min_child_weight': 5, 'min_child_samples': 100, 'subsample': 0.6778863910459726, 'colsample_bytree': 0.5769868850241562, 'num_leaves': 26, 'max_bin': 420, 'reg_alpha': 0.5410623964802436, 'reg_lambda': 0.30516236307833594, 'n_estimators': 249}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:39,988] Trial 12 finished with value: 0.5621506011606224 and parameters: {'learning_rate': 0.08108907102995797, 'min_child_weight': 2, 'min_child_samples': 27, 'subsample': 0.5738188993313342, 'colsample_bytree': 0.9946938427216414, 'num_leaves': 189, 'max_bin': 356, 'reg_alpha': 0.9373011896905379, 'reg_lambda': 0.11031324648498309, 'n_estimators': 416}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:40,449] Trial 31 finished with value: 0.4377381152682478 and parameters: {'learning_rate': 0.035804747117768126, 'min_child_weight': 5, 'min_child_samples': 65, 'subsample': 0.7528190296565535, 'colsample_bytree': 0.5872813483100431, 'num_leaves': 29, 'max_bin': 472, 'reg_alpha': 0.5480261124713365, 'reg_lambda': 0.4376563185478355, 'n_estimators': 241}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:40,627] Trial 17 finished with value: 0.5006999331694876 and parameters: {'learning_rate': 0.06104723764709379, 'min_child_weight': 1, 'min_child_samples': 100, 'subsample': 0.8606057917698734, 'colsample_bytree': 0.6577341718050157, 'num_leaves': 230, 'max_bin': 407, 'reg_alpha': 0.359732676774059, 'reg_lambda': 0.36192030888304194, 'n_estimators': 498}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:40,972] Trial 26 finished with value: 0.447445338681757 and parameters: {'learning_rate': 0.035959490475487715, 'min_child_weight': 5, 'min_child_samples': 26, 'subsample': 0.7115133457935656, 'colsample_bytree': 0.7163629028971549, 'num_leaves': 39, 'max_bin': 437, 'reg_alpha': 0.2950430184176013, 'reg_lambda': 0.38032244697531725, 'n_estimators': 470}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:41,227] Trial 24 finished with value: 0.4367135304929154 and parameters: {'learning_rate': 0.010265849184150806, 'min_child_weight': 1, 'min_child_samples': 24, 'subsample': 0.6074894166288659, 'colsample_bytree': 0.5774283545414163, 'num_leaves': 48, 'max_bin': 339, 'reg_alpha': 0.24624376022456074, 'reg_lambda': 0.24831571446298714, 'n_estimators': 500}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:42,162] Trial 32 finished with value: 0.43947198549422223 and parameters: {'learning_rate': 0.048988127177791385, 'min_child_weight': 5, 'min_child_samples': 70, 'subsample': 0.7707937407533125, 'colsample_bytree': 0.5832998188523739, 'num_leaves': 24, 'max_bin': 476, 'reg_alpha': 0.5366933852926657, 'reg_lambda': 0.42284419732963857, 'n_estimators': 250}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:43,344] Trial 37 finished with value: 0.43979929101336396 and parameters: {'learning_rate': 0.049660251459212046, 'min_child_weight': 3, 'min_child_samples': 67, 'subsample': 0.9091269007549276, 'colsample_bytree': 0.6195902741552181, 'num_leaves': 19, 'max_bin': 468, 'reg_alpha': 0.5844786686486607, 'reg_lambda': 0.46363013970085043, 'n_estimators': 301}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:43,485] Trial 38 finished with value: 0.437795769642849 and parameters: {'learning_rate': 0.047691529081180954, 'min_child_weight': 3, 'min_child_samples': 68, 'subsample': 0.7592895834452749, 'colsample_bytree': 0.5039006543215696, 'num_leaves': 18, 'max_bin': 318, 'reg_alpha': 0.5829784770627279, 'reg_lambda': 0.4552551100390191, 'n_estimators': 302}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:44,065] Trial 35 finished with value: 0.43841391153298065 and parameters: {'learning_rate': 0.04561879940626924, 'min_child_weight': 7, 'min_child_samples': 67, 'subsample': 0.771504474230362, 'colsample_bytree': 0.6250424256506686, 'num_leaves': 23, 'max_bin': 473, 'reg_alpha': 0.5909216864086291, 'reg_lambda': 0.4585089829827798, 'n_estimators': 309}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:44,303] Trial 36 finished with value: 0.4397886068942155 and parameters: {'learning_rate': 0.04843728177746808, 'min_child_weight': 3, 'min_child_samples': 69, 'subsample': 0.7809690711410261, 'colsample_bytree': 0.5007179244267846, 'num_leaves': 26, 'max_bin': 469, 'reg_alpha': 0.5780344549927005, 'reg_lambda': 0.4517290732368492, 'n_estimators': 295}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:44,507] Trial 39 finished with value: 0.43768755672504356 and parameters: {'learning_rate': 0.04875846702699168, 'min_child_weight': 3, 'min_child_samples': 65, 'subsample': 0.6523744205083752, 'colsample_bytree': 0.5512835388508985, 'num_leaves': 15, 'max_bin': 311, 'reg_alpha': 0.5876364715072435, 'reg_lambda': 0.5301871870795903, 'n_estimators': 293}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:45,089] Trial 33 finished with value: 0.448785966059271 and parameters: {'learning_rate': 0.05261924610437119, 'min_child_weight': 5, 'min_child_samples': 69, 'subsample': 0.766875105775308, 'colsample_bytree': 0.5793776955117507, 'num_leaves': 28, 'max_bin': 415, 'reg_alpha': 0.5424503914517544, 'reg_lambda': 0.4389674724122851, 'n_estimators': 485}. Best is trial 14 with value: 0.4363038681910591.
# [I 2021-09-28 23:39:45,259] Trial 40 finished with value: 0.4357589547507936 and parameters: {'learning_rate': 0.01639421280958577, 'min_child_weight': 2, 'min_child_samples': 63, 'subsample': 0.6565376691631659, 'colsample_bytree': 0.5459085215854649, 'num_leaves': 11, 'max_bin': 316, 'reg_alpha': 0.472360146583942, 'reg_lambda': 0.5574875401806826, 'n_estimators': 300}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39
. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39:54,170] Trial 47 finished with value: 0.44300854558798525 and parameters: {'learning_rate': 0.019787095377359412, 'min_child_weight': 2, 'min_child_samples': 47, 'subsample': 0.5592365959372826, 'colsample_bytree': 0.5361924999279801, 'num_leaves': 80, 'max_bin': 281, 'reg_alpha': 0.43430022854247996, 'reg_lambda': 0.6157532358391264, 'n_estimators': 390}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39:55,085] Trial 55 finished with value: 0.4386291330549334 and parameters: {'learning_rate': 0.07433205333815401, 'min_child_weight': 6, 'min_child_samples': 56, 'subsample': 0.6117516416004319, 'colsample_bytree': 0.5250206354393147, 'num_leaves': 10, 'max_bin': 341, 'reg_alpha': 0.19274057679679557, 'reg_lambda': 0.6172190431982532, 'n_estimators': 325}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39:56,585] Trial 50 finished with value: 0.44561111528768216 and parameters: {'learning_rate': 0.023729374992377462, 'min_child_weight': 2, 'min_child_samples': 58, 'subsample': 0.5551228860545363, 'colsample_bytree': 0.559732860354578, 'num_leaves': 122, 'max_bin': 374, 'reg_alpha': 0.6273582992246848, 'reg_lambda': 0.6459735282307797, 'n_estimators': 319}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39:57,331] Trial 51 finished with value: 0.45958887777005025 and parameters: {'learning_rate': 0.04128854018797721, 'min_child_weight': 6, 'min_child_samples': 61, 'subsample': 0.561723240565096, 'colsample_bytree': 0.5309126462071362, 'num_leaves': 92, 'max_bin': 335, 'reg_alpha': 0.6483236779203374, 'reg_lambda': 0.6197600492078813, 'n_estimators': 389}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39:58,206] Trial 49 finished with value: 0.445262937295429 and parameters: {'learning_rate': 0.02146808010679909, 'min_child_weight': 2, 'min_child_samples': 57, 'subsample': 0.6484816851278629, 'colsample_bytree': 0.5474767129911619, 'num_leaves': 255, 'max_bin': 273, 'reg_alpha': 0.6414490589701402, 'reg_lambda': 0.628254135387437, 'n_estimators': 324}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39:58,573] Trial 56 finished with value: 0.4511365600153405 and parameters: {'learning_rate': 0.04227012445554678, 'min_child_weight': 6, 'min_child_samples': 57, 'subsample': 0.6093545059958068, 'colsample_bytree': 0.8434635998467427, 'num_leaves': 53, 'max_bin': 371, 'reg_alpha': 0.6549573560428094, 'reg_lambda': 0.6235164558272279, 'n_estimators': 326}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:39:59,672] Trial 52 finished with value: 0.46124573091494 and parameters: {'learning_rate': 0.042137991707199104, 'min_child_weight': 6, 'min_child_samples': 56, 'subsample': 0.5465086130907743, 'colsample_bytree': 0.5340445675315731, 'num_leaves': 125, 'max_bin': 341, 'reg_alpha': 0.6415958814085493, 'reg_lambda': 0.6211704770689283, 'n_estimators': 324}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:00,329] Trial 58 finished with value: 0.44484606880046523 and parameters: {'learning_rate': 0.04177203017267481, 'min_child_weight': 6, 'min_child_samples': 63, 'subsample': 0.7369661369145012, 'colsample_bytree': 0.822534083096738, 'num_leaves': 53, 'max_bin': 334, 'reg_alpha': 0.7179590302871102, 'reg_lambda': 0.7668919528527871, 'n_estimators': 221}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:00,487] Trial 59 finished with value: 0.44159078780090405 and parameters: {'learning_rate': 0.05440526608297591, 'min_child_weight': 3, 'min_child_samples': 76, 'subsample': 0.7432818809119913, 'colsample_bytree': 0.6088683470857541, 'num_leaves': 52, 'max_bin': 371, 'reg_alpha': 0.7689949906885463, 'reg_lambda': 0.7660979086136613, 'n_estimators': 168}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:01,156] Trial 60 finished with value: 0.43836945425884566 and parameters: {'learning_rate': 0.03936146601652039, 'min_child_weight': 3, 'min_child_samples': 81, 'subsample': 0.699700875983298, 'colsample_bytree': 0.6024346359879322, 'num_leaves': 37, 'max_bin': 370, 'reg_alpha': 0.7602676937811612, 'reg_lambda': 0.8240858730588417, 'n_estimators': 217}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:01,438] Trial 61 finished with value: 0.4421708823408361 and parameters: {'learning_rate': 0.055074111913217275, 'min_child_weight': 3, 'min_child_samples': 78, 'subsample': 0.7412379088461735, 'colsample_bytree': 0.6092979470153688, 'num_leaves': 37, 'max_bin': 492, 'reg_alpha': 0.7242254102316599, 'reg_lambda': 0.7822633979891495, 'n_estimators': 213}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:01,744] Trial 62 finished with value: 0.43893327864023035 and parameters: {'learning_rate': 0.05454017081441648, 'min_child_weight': 1, 'min_child_samples': 75, 'subsample': 0.7366608028665379, 'colsample_bytree': 0.6041403665453967, 'num_leaves': 12, 'max_bin': 248, 'reg_alpha': 0.7339189156104631, 'reg_lambda': 0.7330855254329954, 'n_estimators': 366}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:01,990] Trial 64 finished with value: 0.43600700713759066 and parameters: {'learning_rate': 0.028869059966172103, 'min_child_weight': 1, 'min_child_samples': 83, 'subsample': 0.6892711800865117, 'colsample_bytree': 0.6436944199406205, 'num_leaves': 14, 'max_bin': 252, 'reg_alpha': 0.32468931678468915, 'reg_lambda': 0.1853963291558886, 'n_estimators': 250}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:02,264] Trial 67 finished with value: 0.4627457220274223 and parameters: {'learning_rate': 0.0313393729930621, 'min_child_weight': 7, 'min_child_samples': 37, 'subsample': 0.520641082693112, 'colsample_bytree': 0.6421448314753959, 'num_leaves': 2, 'max_bin': 314, 'reg_alpha': 0.3340954560636359, 'reg_lambda': 0.4980498514417756, 'n_estimators': 255}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:02,640] Trial 63 finished with value: 0.4375738195431562 and parameters: {'learning_rate': 0.014630820317329256, 'min_child_weight': 1, 'min_child_samples': 74, 'subsample': 0.6994153152156267, 'colsample_bytree': 0.6469025949111722, 'num_leaves': 36, 'max_bin': 488, 'reg_alpha': 0.09504221634674642, 'reg_lambda': 0.1573706200675593, 'n_estimators': 171}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:03,109] Trial 54 finished with value: 0.4636943142820613 and parameters: {'learning_rate': 0.04091954164118042, 'min_child_weight': 6, 'min_child_samples': 35, 'subsample': 0.5621317960419956, 'colsample_bytree': 0.5291140333847822, 'num_leaves': 131, 'max_bin': 372, 'reg_alpha': 0.6417277962384361, 'reg_lambda': 0.6515456119637862, 'n_estimators': 321}. Best is trial 40 with value: 0.4357589547507936.
# [I 2021-09-28 23:40:03,488] Trial 65 finished with value: 0.43559625662770574 and parameters: {'learning_rate': 0.015335662711771579, 'min_child_weight': 1, 'min_child_samples': 73, 'subsample': 0.5206970838779317, 'colsample_bytree': 0.6501727265265076, 'num_leaves': 11, 'max_bin': 489, 'reg_alpha': 0.09012828330927225, 'reg_lambda': 0.3947030169306577, 'n_estimators': 364}. Best is trial 65 with value: 0.43559625662770574.
. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:07,677] Trial 57 finished with value: 0.47616154902339325 and parameters: {'learning_rate': 0.04215689513232185, 'min_child_weight': 1, 'min_child_samples': 34, 'subsample': 0.5228117785845412, 'colsample_bytree': 0.8144574636324812, 'num_leaves': 123, 'max_bin': 373, 'reg_alpha': 0.6539707179133287, 'reg_lambda': 0.7629276250280208, 'n_estimators': 361}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:09,390] Trial 80 finished with value: 0.4423829353126259 and parameters: {'learning_rate': 0.015141999576152329, 'min_child_weight': 1, 'min_child_samples': 82, 'subsample': 0.6876806174080453, 'colsample_bytree': 0.7016878499355306, 'num_leaves': 176, 'max_bin': 246, 'reg_alpha': 0.12227078692524161, 'reg_lambda': 0.2731690805753334, 'n_estimators': 122}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:09,774] Trial 75 finished with value: 0.4442501370773433 and parameters: {'learning_rate': 0.02708689397396714, 'min_child_weight': 1, 'min_child_samples': 89, 'subsample': 0.5054082957238816, 'colsample_bytree': 0.6904373070853256, 'num_leaves': 45, 'max_bin': 225, 'reg_alpha': 0.40392157044152, 'reg_lambda': 0.2830161331898485, 'n_estimators': 447}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:10,150] Trial 72 finished with value: 0.4377722109968717 and parameters: {'learning_rate': 0.014344387612993104, 'min_child_weight': 1, 'min_child_samples': 73, 'subsample': 0.524659124409971, 'colsample_bytree': 0.6623176346605035, 'num_leaves': 43, 'max_bin': 455, 'reg_alpha': 0.05659298089512201, 'reg_lambda': 0.17440190775180198, 'n_estimators': 438}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:11,397] Trial 74 finished with value: 0.4461179468979637 and parameters: {'learning_rate': 0.027643325930887114, 'min_child_weight': 1, 'min_child_samples': 89, 'subsample': 0.5078847908549085, 'colsample_bytree': 0.6739430300841874, 'num_leaves': 189, 'max_bin': 455, 'reg_alpha': 0.20917395681140233, 'reg_lambda': 0.27374098268970437, 'n_estimators': 236}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:12,314] Trial 84 finished with value: 0.4356429930138926 and parameters: {'learning_rate': 0.016877518267233885, 'min_child_weight': 1, 'min_child_samples': 92, 'subsample': 0.5978147097147741, 'colsample_bytree': 0.6692153147768933, 'num_leaves': 16, 'max_bin': 210, 'reg_alpha': 0.16870769677519892, 'reg_lambda': 0.9905525487646163, 'n_estimators': 449}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:13,494] Trial 85 finished with value: 0.44122646445550256 and parameters: {'learning_rate': 0.032930679702558696, 'min_child_weight': 1, 'min_child_samples': 85, 'subsample': 0.5934915961140937, 'colsample_bytree': 0.7084260720159621, 'num_leaves': 34, 'max_bin': 211, 'reg_alpha': 0.18006256359570635, 'reg_lambda': 0.11032867267255086, 'n_estimators': 338}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:13,914] Trial 83 finished with value: 0.44288688200556614 and parameters: {'learning_rate': 0.026544744330864026, 'min_child_weight': 1, 'min_child_samples': 94, 'subsample': 0.5072193836488137, 'colsample_bytree': 0.7454802563873351, 'num_leaves': 33, 'max_bin': 217, 'reg_alpha': 0.17696295277178264, 'reg_lambda': 0.059030925036691995, 'n_estimators': 446}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40
. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:19,887] Trial 95 finished with value: 0.4355956803979394 and parameters: {'learning_rate': 0.01248774830157083, 'min_child_weight': 1, 'min_child_samples': 79, 'subsample': 0.5398698620902981, 'colsample_bytree': 0.6617434686275337, 'num_leaves': 11, 'max_bin': 235, 'reg_alpha': 0.22651282193929706, 'reg_lambda': 0.8717956632748229, 'n_estimators': 376}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:20,347] Trial 91 finished with value: 0.436969565476694 and parameters: {'learning_rate': 0.02339746372145777, 'min_child_weight': 1, 'min_child_samples': 79, 'subsample': 0.6293087856048597, 'colsample_bytree': 0.6362415012978478, 'num_leaves': 20, 'max_bin': 249, 'reg_alpha': 0.1235872696878369, 'reg_lambda': 0.9432770825091239, 'n_estimators': 411}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:20,617] Trial 96 finished with value: 0.43693844929109776 and parameters: {'learning_rate': 0.012016716494184667, 'min_child_weight': 2, 'min_child_samples': 84, 'subsample': 0.6710357594103082, 'colsample_bytree': 0.620275750255088, 'num_leaves': 8, 'max_bin': 236, 'reg_alpha': 0.22314694117476985, 'reg_lambda': 0.21086136390183147, 'n_estimators': 464}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:21,748] Trial 92 finished with value: 0.4585282607166334 and parameters: {'learning_rate': 0.09205541743704652, 'min_child_weight': 1, 'min_child_samples': 85, 'subsample': 0.6206036846496471, 'colsample_bytree': 0.6293289535217967, 'num_leaves': 24, 'max_bin': 238, 'reg_alpha': 0.1573637360715746, 'reg_lambda': 0.2091987392676662, 'n_estimators': 474}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:22,198] Trial 99 finished with value: 0.4470369142204822 and parameters: {'learning_rate': 0.09117195886923342, 'min_child_weight': 2, 'min_child_samples': 84, 'subsample': 0.5401844329080074, 'colsample_bytree': 0.7298126530723054, 'num_leaves': 14, 'max_bin': 225, 'reg_alpha': 0.09718384386832918, 'reg_lambda': 0.20565914147764955, 'n_estimators': 404}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:22,811] Trial 82 finished with value: 0.44678317820318664 and parameters: {'learning_rate': 0.01571566649279448, 'min_child_weight': 1, 'min_child_samples': 92, 'subsample': 0.5944778671795102, 'colsample_bytree': 0.6956536342283464, 'num_leaves': 173, 'max_bin': 248, 'reg_alpha': 0.15102928377407818, 'reg_lambda': 0.2976934540291744, 'n_estimators': 449}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:22,970] Trial 81 finished with value: 0.4494933684074644 and parameters: {'learning_rate': 0.015510563514380698, 'min_child_weight': 1, 'min_child_samples': 83, 'subsample': 0.5351430426887398, 'colsample_bytree': 0.7608322688005491, 'num_leaves': 162, 'max_bin': 246, 'reg_alpha': 0.11944925562368786, 'reg_lambda': 0.28648963362543733, 'n_estimators': 441}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:23,298] Trial 97 finished with value: 0.43549901841936683 and parameters: {'learning_rate': 0.01287524702705986, 'min_child_weight': 2, 'min_child_samples': 85, 'subsample': 0.5437538846472285, 'colsample_bytree': 0.6320474523048911, 'num_leaves': 14, 'max_bin': 236, 'reg_alpha': 0.10463703651802378, 'reg_lambda': 0.20437269037418973, 'n_estimators': 475}. Best is trial 66 with value: 0.4354161806078784.
# [I 2021-09-28 23:40:23,556] Trial 100 finished with value: 0.4351983530980097 and parameters: {'learning_rate': 0.012788219635734883, 'min_child_weight': 2, 'min_child_samples': 86, 'subsample': 0.5382676533703065, 'colsample_bytree': 0.6566335305845556, 'num_leaves': 14, 'max_bin': 222, 'reg_alpha': 0.08833899789678763, 'reg_lambda': 0.19906272486196294, 'n_estimators': 400}. Best is trial 100 with value: 0.4351983530980097.
# [I 2021-09-28 23:40:24,374] Trial 102 finished with value: 0.43533625363894085 and parameters: {'learning_rate': 0.01298331382123416, 'min_child_weight': 2, 'min_child_samples': 17, 'subsample': 0.5340003112209964, 'colsample_bytree': 0.6538553487608739, 'num_leaves': 14, 'max_bin': 223, 'reg_alpha': 0.2924625030604365, 'reg_lambda': 0.4001319590635606, 'n_estimators': 284}. Best is trial 100 with value: 0.4351983530980097.
# [I 2021-09-28 23:40:24,893] Trial 98 finished with value: 0.4362972615947239 and parameters: {'learning_rate': 0.01705395841514469, 'min_child_weight': 1, 'min_child_samples': 84, 'subsample': 0.6381729407040565, 'colsample_bytree': 0.6209585710000266, 'num_leaves': 25, 'max_bin': 224, 'reg_alpha': 0.09753665135867046, 'reg_lambda': 0.41085863123453903, 'n_estimators': 377}. Best is trial 100 with value: 0.4351983530980097.
# [I 2021-09-28 23:40:25,153] Trial 101 finished with value: 0.43533332335205205 and parameters: {'learning_rate': 0.013456155128740658, 'min_child_weight': 1, 'min_child_samples': 97, 'subsample': 0.538287228114117, 'colsample_bytree': 0.6599490608797197, 'num_leaves': 25, 'max_bin': 220, 'reg_alpha': 0.0862277152106771, 'reg_lambda': 0.4872213913731835, 'n_estimators': 375}. Best is trial 100 with value: 0.4351983530980097.
# [I 2021-09-28 23:40:25,911] Trial 105 finished with value: 0.4350751217691661 and parameters: {'learning_rate': 0.012974133908489952, 'min_child_weight': 2, 'min_child_samples': 87, 'subsample': 0.7206648181971206, 'colsample_bytree': 0.6597680952366232, 'num_leaves': 15, 'max_bin': 218, 'reg_alpha': 0.301939581605565, 'reg_lambda': 0.41816321244954124, 'n_estimators': 377}. Best is trial 105 with value: 0.4350751217691661.
# [I 2021-09-28 23:40:25,999] Trial 110 finished with value: 0.4506141508352758 and parameters: {'learning_rate': 0.013646043983622232, 'min_child_weight': 2, 'min_child_samples': 97, 'subsample': 0.5726124048552647, 'colsample_bytree': 0.6587167994581131, 'num_leaves': 3, 'max_bin': 217, 'reg_alpha': 0.024209637371169143, 'reg_lambda': 0.5089389672205824, 'n_estimators': 376}. Best is trial 105 with value: 0.4350751217691661.
# [I 2021-09-28 23:40:26,331] Trial 109 finished with value: 0.43983581889828693 and parameters: {'learning_rate': 0.013209323570376958, 'min_child_weight': 2, 'min_child_samples': 52, 'subsample': 0.5703800875864655, 'colsample_bytree': 0.6583576738737847, 'num_leaves': 5, 'max_bin': 213, 'reg_alpha': 0.2796588711770338, 'reg_lambda': 0.4803845061295948, 'n_estimators': 373}. Best is trial 105 with value: 0.4350751217691661.
# [I 2021-09-28 23:40:26,571] Trial 104 finished with value: 0.4349764278312724 and parameters: {'learning_rate': 0.013282406387535516, 'min_child_weight': 2, 'min_child_samples': 87, 'subsample': 0.5425039115360802, 'colsample_bytree': 0.6562557996392016, 'num_leaves': 16, 'max_bin': 222, 'reg_alpha': 0.29780054311189946, 'reg_lambda': 0.23775425955191853, 'n_estimators': 377}. Best is trial 104 with value: 0.4349764278312724.
# [I 2021-09-28 23:40:27,086] Trial 103 finished with value: 0.4354390230918513 and parameters: {'learning_rate': 0.013563608956503409, 'min_child_weight': 1, 'min_child_samples': 97, 'subsample': 0.5734558551817269, 'colsample_bytree': 0.6567687917969032, 'num_leaves': 25, 'max_bin': 218, 'reg_alpha': 0.2932147547695316, 'reg_lambda': 0.40448675691203806, 'n_estimators': 382}. Best is trial 104 with value: 0.4349764278312724.
# [I 2021-09-28 23:40:27,360] Trial 111 finished with value: 0.4399741400483128 and parameters: {'learning_rate': 0.013131289497282091, 'min_child_weight': 2, 'min_child_samples': 97, 'subsample': 0.5743428824667598, 'colsample_bytree': 0.6548903854609822, 'num_leaves': 5, 'max_bin': 231, 'reg_alpha': 0.28221196285252237, 'reg_lambda': 0.47975444014670865, 'n_estimators': 374}. Best is trial 104 with value: 0.4349764278312724.
# [I 2021-09-28 23:40:27,611] Trial 106 finished with value: 0.4362887850808327 and parameters: {'learning_rate': 0.017845052636498143, 'min_child_weight': 2, 'min_child_samples': 97, 'subsample': 0.7173160959403388, 'colsample_bytree': 0.6573592959763688, 'num_leaves': 25, 'max_bin': 218, 'reg_alpha': 0.27423827962686625, 'reg_lambda': 0.24136618909069882, 'n_estimators': 376}. Best is trial 104 with value: 0.4349764278312724.
# [I 2021-09-28 23:40:27,869] Trial 107 finished with value: 0.43558513302515794 and parameters: {'learning_rate': 0.013320520941602621, 'min_child_weight': 2, 'min_child_samples': 91, 'subsample': 0.5708720920042837, 'colsample_bytree': 0.7124959465489025, 'num_leaves': 26, 'max_bin': 218, 'reg_alpha': 0.02431742980583483, 'reg_lambda': 0.2397059868707978, 'n_estimators': 373}. Best is trial 104 with value: 0.4349764278312724.
# [I 2021-09-28 23:40:29,273] Trial 108 finished with value: 0.43499429212902746 and parameters: {'learning_rate': 0.013177470655063058, 'min_child_weight': 2, 'min_child_samples': 18, 'subsample': 0.5772728222546836, 'colsample_bytree': 0.6570065229037564, 'num_leaves': 26, 'max_bin': 219, 'reg_alpha': 0.2920131062645707, 'reg_lambda': 0.4032130222589696, 'n_estimators': 378}. Best is trial 104 with value: 0.4349764278312724.
# ...
# [I 2021-09-28 23:48:36,679] Trial 967 finished with value: 0.4363698135214352 and parameters: {'learning_rate': 0.01391197990253665, 'min_child_weight': 1, 'min_child_samples': 43, 'subsample': 0.6475985427011908, 'colsample_bytree': 0.9792710293862886, 'num_leaves': 8, 'max_bin': 381, 'reg_alpha': 0.6178077561828543, 'reg_lambda': 0.971075430248348, 'n_estimators': 337}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:36,924] Trial 966 finished with value: 0.43615652782339503 and parameters: {'learning_rate': 0.018886168148528414, 'min_child_weight': 1, 'min_child_samples': 43, 'subsample': 0.6724557892757415, 'colsample_bytree': 0.9768826531524712, 'num_leaves': 9, 'max_bin': 379, 'reg_alpha': 0.6191971459958647, 'reg_lambda': 0.9679024491093015, 'n_estimators': 341}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:37,599] Trial 968 finished with value: 0.435789287365535 and parameters: {'learning_rate': 0.013847320797751587, 'min_child_weight': 1, 'min_child_samples': 44, 'subsample': 0
. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:43,707] Trial 953 finished with value: 0.4453599350860672 and parameters: {'learning_rate': 0.013507234356859058, 'min_child_weight': 1, 'min_child_samples': 46, 'subsample': 0.6703550341281604, 'colsample_bytree': 0.954948347717661, 'num_leaves': 172, 'max_bin': 408, 'reg_alpha': 0.564877078835924, 'reg_lambda': 0.9134972046265579, 'n_estimators': 322}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:44,913] Trial 978 finished with value: 0.43417769592302824 and parameters: {'learning_rate': 0.01768018850509057, 'min_child_weight': 1, 'min_child_samples': 44, 'subsample': 0.6886056963974319, 'colsample_bytree': 0.9831590344966115, 'num_leaves': 17, 'max_bin': 383, 'reg_alpha': 0.6885918901644712, 'reg_lambda': 0.9484411886010289, 'n_estimators': 280}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:45,331] Trial 979 finished with value: 0.4348788657919459 and parameters: {'learning_rate': 0.01763218978449162, 'min_child_weight': 1, 'min_child_samples': 40, 'subsample': 0.6859811176193464, 'colsample_bytree': 0.9821141869947373, 'num_leaves': 21, 'max_bin': 379, 'reg_alpha': 0.6741968930234834, 'reg_lambda': 0.5117205689067453, 'n_estimators': 278}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:46,163] Trial 981 finished with value: 0.43433046569275774 and parameters: {'learning_rate': 0.015257231095332039, 'min_child_weight': 1, 'min_child_samples': 41, 'subsample': 0.9823706136117466, 'colsample_bytree': 0.984240114530011, 'num_leaves': 22, 'max_bin': 388, 'reg_alpha': 0.6880379814826764, 'reg_lambda': 0.9997616396653144, 'n_estimators': 264}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:46,937] Trial 980 finished with value: 0.4355807393046887 and parameters: {'learning_rate': 0.016920757579315583, 'min_child_weight': 1, 'min_child_samples': 90, 'subsample': 0.981411064571124, 'colsample_bytree': 0.5644474621107252, 'num_leaves': 21, 'max_bin': 391, 'reg_alpha': 0.6908955191864627, 'reg_lambda': 0.9998749698179297, 'n_estimators': 351}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:47,533] Trial 983 finished with value: 0.44149784018993765 and parameters: {'learning_rate': 0.04330396836600991, 'min_child_weight': 1, 'min_child_samples': 40, 'subsample': 0.9805279873951723, 'colsample_bytree': 0.9849013240062834, 'num_leaves': 23, 'max_bin': 387, 'reg_alpha': 0.6978092000726632, 'reg_lambda': 0.9993773138472638, 'n_estimators': 336}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:48,267] Trial 982 finished with value: 0.4345659711553467 and parameters: {'learning_rate': 0.015164007306538867, 'min_child_weight': 1, 'min_child_samples': 40, 'subsample': 0.8767716747105275, 'colsample_bytree': 0.9823313249043735, 'num_leaves': 22, 'max_bin': 385, 'reg_alpha': 0.6574924007739386, 'reg_lambda': 0.9513613592071435, 'n_estimators': 336}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:48,681] Trial 984 finished with value: 0.4402136636501882 and parameters: {'learning_rate': 0.04364335466962246, 'min_child_weight': 1, 'min_child_samples': 42, 'subsample': 0.7182082373364047, 'colsample_bytree': 0.9828109716880878, 'num_leaves': 23, 'max_bin': 401, 'reg_alpha': 0.6991297485054332, 'reg_lambda': 0.23831581434401933, 'n_estimators': 282}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:48,748] Trial 986 finished with value: 0.4363207664024006 and parameters: {'learning_rate': 0.019669015770956755, 'min_child_weight': 1, 'min_child_samples': 41, 'subsample': 0.7134928010709289, 'colsample_bytree': 0.9646134883496191, 'num_leaves': 9, 'max_bin': 388, 'reg_alpha': 0.6593345665404147, 'reg_lambda': 0.9432993126257657, 'n_estimators': 335}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:49,039] Trial 973 finished with value: 0.43920827659778083 and parameters: {'learning_rate': 0.011696628813480546, 'min_child_weight': 1, 'min_child_samples': 32, 'subsample': 0.9999330939484956, 'colsample_bytree': 0.9679481106541651, 'num_leaves': 96, 'max_bin': 384, 'reg_alpha': 0.6620798578307581, 'reg_lambda': 0.9491941535659966, 'n_estimators': 277}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:49,586] Trial 987 finished with value: 0.43591965059893906 and parameters: {'learning_rate': 0.022367414227634497, 'min_child_weight': 1, 'min_child_samples': 40, 'subsample': 0.998561439417701, 'colsample_bytree': 0.9661546817787009, 'num_leaves': 9, 'max_bin': 401, 'reg_alpha': 0.7150453956642292, 'reg_lambda': 0.9439487985102814, 'n_estimators': 283}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:50,256] Trial 985 finished with value: 0.43487114722839804 and parameters: {'learning_rate': 0.01586492112546186, 'min_child_weight': 1, 'min_child_samples': 41, 'subsample': 0.7073805557057411, 'colsample_bytree': 0.9828824262641277, 'num_leaves': 23, 'max_bin': 395, 'reg_alpha': 0.7192423907614275, 'reg_lambda': 0.9437730120596862, 'n_estimators': 347}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:50,723] Trial 988 finished with value: 0.4355333050304577 and parameters: {'learning_rate': 0.015398837903358803, 'min_child_weight': 5, 'min_child_samples': 42, 'subsample': 0.6780307180796368, 'colsample_bytree': 0.9652933860882612, 'num_leaves': 10, 'max_bin': 382, 'reg_alpha': 0.7033356087438178, 'reg_lambda': 0.9003749987668177, 'n_estimators': 345}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:51,862] Trial 992 finished with value: 0.4354504145771179 and parameters: {'learning_rate': 0.015611215287899636, 'min_child_weight': 1, 'min_child_samples': 42, 'subsample': 0.6978739858753911, 'colsample_bytree': 0.9718690466791882, 'num_leaves': 11, 'max_bin': 367, 'reg_alpha': 0.7174645377311948, 'reg_lambda': 0.9392400639836053, 'n_estimators': 310}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:51,911] Trial 990 finished with value: 0.4361853621043523 and parameters: {'learning_rate': 0.022262150006229185, 'min_child_weight': 1, 'min_child_samples': 42, 'subsample': 0.7015413303092009, 'colsample_bytree': 0.9719433182938295, 'num_leaves': 11, 'max_bin': 392, 'reg_alpha': 0.7020067185255405, 'reg_lambda': 0.9279671959889406, 'n_estimators': 346}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:52,328] Trial 989 finished with value: 0.4366776323494556 and parameters: {'learning_rate': 0.019441030476546585, 'min_child_weight': 1, 'min_child_samples': 42, 'subsample': 0.7093694630238949, 'colsample_bytree': 0.967038622583136, 'num_leaves': 10, 'max_bin': 369, 'reg_alpha': 0.7059821909707704, 'reg_lambda': 0.9363382071764846, 'n_estimators': 464}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:52,940] Trial 964 finished with value: 0.4463996880485256 and parameters: {'learning_rate': 0.014378997872315034, 'min_child_weight': 1, 'min_child_samples': 32, 'subsample': 0.984001883078406, 'colsample_bytree': 0.9789047573536835, 'num_leaves': 173, 'max_bin': 385, 'reg_alpha': 0.6242438655303043, 'reg_lambda': 0.9656906229958446, 'n_estimators': 308}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:52,978] Trial 993 finished with value: 0.43448934803914646 and parameters: {'learning_rate': 0.016117481742677384, 'min_child_weight': 1, 'min_child_samples': 43, 'subsample': 0.7741388857302455, 'colsample_bytree': 0.9739025549317768, 'num_leaves': 13, 'max_bin': 369, 'reg_alpha': 0.6935870361000926, 'reg_lambda': 0.9033253670912146, 'n_estimators': 309}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:53,348] Trial 991 finished with value: 0.43721626929767593 and parameters: {'learning_rate': 0.021566222326579492, 'min_child_weight': 1, 'min_child_samples': 42, 'subsample': 0.671797038612242, 'colsample_bytree': 0.9713004484061115, 'num_leaves': 11, 'max_bin': 373, 'reg_alpha': 0.7150302598172358, 'reg_lambda': 0.8989258637862025, 'n_estimators': 472}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:53,756] Trial 994 finished with value: 0.4346467563407824 and parameters: {'learning_rate': 0.01564585555477403, 'min_child_weight': 1, 'min_child_samples': 43, 'subsample': 0.6870912046642856, 'colsample_bytree': 0.9724298877814223, 'num_leaves': 13, 'max_bin': 372, 'reg_alpha': 0.6856827365530456, 'reg_lambda': 0.9303263684355322, 'n_estimators': 370}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:53,898] Trial 995 finished with value: 0.4344881328244809 and parameters: {'learning_rate': 0.01888756951149905, 'min_child_weight': 1, 'min_child_samples': 47, 'subsample': 0.607796607887642, 'colsample_bytree': 0.9739473513945538, 'num_leaves': 14, 'max_bin': 368, 'reg_alpha': 0.6894598531930503, 'reg_lambda': 0.927127898027859, 'n_estimators': 328}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:55,079] Trial 996 finished with value: 0.43614471890343304 and parameters: {'learning_rate': 0.018866532857477143, 'min_child_weight': 1, 'min_child_samples': 47, 'subsample': 0.6103230267917549, 'colsample_bytree': 0.9997808965905746, 'num_leaves': 29, 'max_bin': 394, 'reg_alpha': 0.6795123323421726, 'reg_lambda': 0.8988477939446483, 'n_estimators': 326}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:55,187] Trial 997 finished with value: 0.43682522347521313 and parameters: {'learning_rate': 0.019246442825251633, 'min_child_weight': 1, 'min_child_samples': 47, 'subsample': 0.6813279305718395, 'colsample_bytree': 0.9815987986632927, 'num_leaves': 29, 'max_bin': 379, 'reg_alpha': 0.6794976750565991, 'reg_lambda': 0.9573115031001416, 'n_estimators': 329}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:55,407] Trial 999 finished with value: 0.4364963319599744 and parameters: {'learning_rate': 0.017439023485568535, 'min_child_weight': 1, 'min_child_samples': 47, 'subsample': 0.9796315968899066, 'colsample_bytree': 0.9837487493132351, 'num_leaves': 29, 'max_bin': 384, 'reg_alpha': 0.6766019106024187, 'reg_lambda': 0.9634932356623569, 'n_estimators': 329}. Best is trial 616 with value: 0.4340122863336259.
# [I 2021-09-28 23:48:56,474] Trial 998 finished with value: 0.4395108314897126 and parameters: {'learning_rate': 0.014104909557691276, 'min_child_weight': 1, 'min_child_samples': 45, 'subsample': 0.7708027588182856, 'colsample_bytree': 0.9835035373128542, 'num_leaves': 72, 'max_bin': 272, 'reg_alpha': 0.6779726176196075, 'reg_lambda': 0.9042931656578126, 'n_estimators': 326}. Best is trial 616 with value: 0.4340122863336259.

# %%
best_params = study.best_params
best_params
# Out:
# {'learning_rate': 0.01224106689079653,
#  'min_child_weight': 1,
#  'min_child_samples': 45,
#  'subsample': 0.9883496133516786,
#  'colsample_bytree': 0.9869822033578003,
#  'num_leaves': 18,
#  'max_bin': 257,
#  'reg_alpha': 0.6063206194546109,
#  'reg_lambda': 0.9924696356405053,
#  'n_estimators': 331}

# %%
# RandomForest, XGBClassifier, LGBMClassifier(BASELINE), LGBMClassifier(최적화) 모델 성능 비교
model = LGBMClassifier(**study.best_params, n_jobs=-1)
model.fit(trn[features], trn.target)
tst_preds = model.predict(tst[features])
pred_proba_list.append(model.predict_proba(tst[features]))

model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)']
result = make_result_df(model_names, pred_proba_list)
result
# Out:
#                            acc  log_loss  roc_score
# RandomForest          0.782997  0.462287   0.676504
# XGBClassifier         0.774542  0.472222   0.694191
# LGBMClassifier(base)  0.783466  0.460133   0.719422
# LGBMClassifier(best)  0.794270  0.453048   0.738295

# %%
# RandomForest, XGBClassifier, LGBMClassifier(BASELINE), LGBMClassifier(최적화) 모델의 roc_curve를 그려보겠습니다.
# roc_curve 함수는 False Positive Rate, True Positive Rate, Threshold를 반환합니다.
fig, ax = plt.subplots(figsize=(8, 6))
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)']
random_x = np.linspace(0, 1, 15)
random_y = np.linspace(0, 1, 15)
ax.plot(random_x, random_y, label='Random', color='black', ls=':', lw=1.5)
for pred_proba, model_name in zip(pred_proba_list, model_names):    
    fprs, tprs, _ = roc_curve(tst.target, pred_proba[:, 1])     
    ax.plot(fprs, tprs, label=model_name)    
ax.legend(loc='lower right') # 범례 생성
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1.1)
ax.set_title('ROC CURVE', fontsize=15, fontweight='bold')
plt.show()
# ROC-CURVE로 모델의 성능을 비교해봅니다.

# %%
# NN 모델
def create_model(trn, numeric, categorical):
    cat_inputs, cat_outputs = [], []
    num_input = layers.Input(shape=(len(numeric), ))
    for col in categorical:
        nunique = trn[col].nunique()    
        embed_dim = int(min(np.ceil(nunique/2), 50))
        cat_input = layers.Input(shape=(1, ))    
        cat_output = layers.Embedding(nunique+1, embed_dim)(cat_input)
        cat_output = layers.SpatialDropout1D(0.3)(cat_output)
        cat_output = layers.Flatten()(cat_output)
        cat_inputs.append(cat_input)
        cat_outputs.append(cat_output)
    x = layers.Concatenate()(cat_outputs + [num_input])    
    x = layers.BatchNormalization()(x)
    x = layers.Dense(256, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dense(128, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    x = layers.BatchNormalization()(x)
    output = layers.Dense(2, activation='softmax')(x)

    model = tf.keras.models.Model([num_input, cat_inputs], output)
    model.compile(
        optimizer=tf.optimizers.Adam(learning_rate=0.01), loss='categorical_crossentropy',
        metrics=['acc'])
    return model

# %%
trn, tst = load_data()
trn, tst = labelencoder(trn, tst)
features = trn.drop('target', axis=1).columns

# numeric feature는 정규화 합니다.
numeric = ['city_development_index', 'training_hours', 'num_missing']
categorical = list(col for col in trn.columns if col not in numeric and col!='target')
for col in numeric:
    ss = StandardScaler()
    trn[col] = ss.fit_transform(trn[col].values.reshape(-1, 1))
    tst[col] = ss.transform(tst[col].values.reshape(-1, 1))
print(trn.shape, tst.shape)
# Out:
# (19158, 14) (2129, 14)

# %%
model = create_model(trn, numeric, categorical)
# 위의 모델은 numric, categorical feature 순으로 데이터를 넣어주어야 한다.
y_trn = to_categorical(trn.target.values)
y_tst = to_categorical(tst.target.values)
ec = EarlyStopping(monitor='val_loss', verbose=0, mode='min', patience=5)
tf_board = TensorBoard(log_dir='logs', histogram_freq=1, embeddings_freq=1)
history = model.fit(
    [trn[numeric].values, list(trn[col].values for col in categorical)], y_trn,
    epochs=100, verbose=1, batch_size=64, validation_split=0.2, shuffle=False,
#     callbacks=[ec, tf_board]
    callbacks=[ec]
)
# Out:
# Epoch 1/100
# 240/240 [==============================] - 6s 9ms/step - loss: 0.5156 - acc: 0.7621 - val_loss: 0.4583 - val_acc: 0.7811
# Epoch 2/100
# 240/240 [==============================] - 2s 6ms/step - loss: 0.4701 - acc: 0.7766 - val_loss: 0.4460 - val_acc: 0.7933
# Epoch 3/100
# 240/240 [==============================] - 2s 7ms/step - loss: 0.4585 - acc: 0.7791 - val_loss: 0.4475 - val_acc: 0.7967
# Epoch 4/100
# 240/240 [==============================] - 1s 6ms/step - loss: 0.4506 - acc: 0.7840 - val_loss: 0.4394 - val_acc: 0.7972
# Epoch 5/100
# 240/240 [==============================] - 1s 6ms/step - loss: 0.4513 - acc: 0.7819 - val_loss: 0.4387 - val_acc: 0.7957
# Epoch 6/100
# 240/240 [==============================] - 1s 6ms/step - loss: 0.4500 - acc: 0.7840 - val_loss: 0.4373 - val_acc: 0.7983
# Epoch 7/100
# 240/240 [==============================] - 1s 5ms/step - loss: 0.4460 - acc: 0.7863 - val_loss: 0.4397 - val_acc: 0.7985
# Epoch 8/100
# 240/240 [==============================] - 2s 6ms/step - loss: 0.4455 - acc: 0.7860 - val_loss: 0.4398 - val_acc: 0.7988
# Epoch 9/100
# 240/240 [==============================] - 1s 5ms/step - loss: 0.4465 - acc: 0.7873 - val_loss: 0.4387 - val_acc: 0.7967
# Epoch 10/100
# 240/240 [==============================] - 1s 5ms/step - loss: 0.4449 - acc: 0.7877 - val_loss: 0.4402 - val_acc: 0.7983
# Epoch 11/100
# 240/240 [==============================] - 1s 5ms/step - loss: 0.4421 - acc: 0.7892 - val_loss: 0.4392 - val_acc: 0.7993

# %%
if len(pred_proba_list)>4:
    pred_proba_list = pred_proba_list[:4]

# NN모델의 예측값을 추가하고
pred_proba_list.append(model.predict([tst[numeric].values, list(tst[col].values for col in categorical)]))
# 총 5가지 모델을 비교
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
result = make_result_df(model_names, pred_proba_list)
result
# Out:
#                            acc  log_loss  roc_score
# RandomForest          0.782997  0.462287   0.676504
# XGBClassifier         0.774542  0.472222   0.694191
# LGBMClassifier(base)  0.783466  0.460133   0.719422
# LGBMClassifier(best)  0.794270  0.453048   0.738295
# NN                    0.786754  0.461618   0.735328

# %%
if len(pred_proba_list)>4:
    pred_proba_list = pred_proba_list[:4]

# NN모델의 예측값을 추가하고
pred_proba_list.append(model.predict([tst[numeric].values, list(tst[col].values for col in categorical)]))
# 총 5가지 모델을 비교
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
result = make_result_df(model_names, pred_proba_list)
result
# Out:
#                            acc  log_loss  roc_score
# RandomForest          0.782997  0.462287   0.676504
# XGBClassifier         0.774542  0.472222   0.694191
# LGBMClassifier(base)  0.783466  0.460133   0.719422
# LGBMClassifier(best)  0.794270  0.453048   0.738295
# NN                    0.786754  0.461618   0.735328

# %%
# NN모델의 예측값을 추가하고
#pred_proba_list.append(model.predict([tst[numeric].values, list(tst[col].values for col in categorical)]))
# 총 5가지 모델을 비교
#model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
#result = make_result_df(model_names, pred_proba_list)
#result

# %%
# 5개 모델을 ROC_CURVE로 비교합니다.
fig, ax = plt.subplots(figsize=(20, 9))
model_names = ['RandomForest', 'XGBClassifier', 'LGBMClassifier(base)', 'LGBMClassifier(best)', 'NN']
random_x = np.linspace(0, 1, 15)
random_y = np.linspace(0, 1, 15)
ax.plot(random_x, random_y, label='Random', color='black', ls=':', lw=1.5)
for pred_proba, model_name in zip(pred_proba_list, model_names):    
    fprs, tprs, _ = roc_curve(tst.target, pred_proba[:, 1])     
    ax.plot(fprs, tprs, label=model_name)    
ax.legend(loc='lower right') # 범례 생성
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_xlim(0, 1)
ax.set_ylim(0, 1.1)
ax.set_title('ROC CURVE', fontsize=15, fontweight='bold')
plt.show()
# ROC-CURVE로 모델의 성능을 비교해봅니다.

# %%
# !tensorboard --logdir=logs
